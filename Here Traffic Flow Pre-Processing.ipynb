# %%
import pandas as pd
import numpy as np
import requests
import json
from sklearn.preprocessing import LabelEncoder, StandardScaler

# %% [markdown]
# **https://developer.here.com/documentation/traffic-api/dev_guide/topics/concepts/flow.html#flow**

# %% [markdown]
# # HERE Traffic flow API
# **Traffic flow data that is similar to DataMall Speed Bands, but instead of a range (minimum and maximum speed), it provides the speed itself and also a jam factor that tells us how congested it is**

# %% [markdown]
# **It also covers more roads (1500+) depending on how we set the parameter**

# %% [markdown]
# **The "in=circle:1.279683,103.809628" parameter in the request url represents a point in the map, and r=20830 represents the radius**

# %%
response = requests.get("https://data.traffic.hereapi.com/v7/flow?in=circle:1.279683,103.809628;r=20830&locationReferencing=shape&apiKey=uAF0ydU9hJ_THCHkwvtSQR5FhTKEWjtX8XynT5rHoPk")

# %%
data = response.json()["results"]

# %%
data
# Out:
# [{'location': {'description': 'Changi South Ave 2',
#    'length': 92.0,
#    'shape': {'links': [{'points': [{'lat': 1.3317399937659502,
#         'lng': 103.96608003415167},
#        {'lat': 1.3319799676537514, 'lng': 103.96619997918606},
#        {'lat': 1.3322200253605843, 'lng': 103.96634004078805},
#        {'lat': 1.3324599992483854, 'lng': 103.9664899930358}],
#       'length': 92.0}]}},
#   'currentFlow': {'speed': 11.666667,
#    'speedUncapped': 11.666667,
#    'freeFlow': 10.277778,
#    'jamFactor': 0.0,
#    'confidence': 0.92,
#    'traversability': 'open'}},
#  {'location': {'description': 'ECP/East Coast Pkwy',
#    'length': 44.0,
#    'shape': {'links': [{'points': [{'lat': 1.3121199700981379,
#         'lng': 103.95154003053904},
#        {'lat': 1.3120300322771072, 'lng': 103.95136996172369},
#        {'lat': 1.311940010637045, 'lng': 103.95119000226259}],
#       'length': 44.0}]}},
#   'currentFlow': {'speed': 17.777779,
#    'speedUncapped': 17.777779,
#    'freeFlow': 13.888889,
#    'jamFactor': 0.0,
#    'confidence': 0.7,
#    'traversability': 'open'}},
#  {'location': {'description': 'Benoi Rd',
#    'length': 511.0,
#    'shape': {'links': [{'points': [{'lat': 1.3087099604308605,
#         'lng': 103.67102002725005},
#        {'lat': 1.3088100403547287, 'lng': 103.67182997055352}],
#       'length': 91.0},
#      {'points': [{'lat': 1.3088100403547287, 'lng': 103.67182997055352},
#        {'lat': 1.3089100364595652, 'lng': 103.67263002321124}],
#       'length': 89.0},
#      {'points': [{'lat': 1.3089100364595652, 'lng': 103.67263002321124},
#        {'lat': 1.3090500142425299, 'lng': 103.67365001700819}],
#       'length': 114.0},
#      {'points': [{'lat': 1.3090500142425299, 'lng': 103.67365001700819},
#        {'lat': 1.3092100247740746, 'lng': 103.67476003244519}],
#       'length': 124.0},
#      {'points': [{'lat': 1.3092100247740746, 'lng': 103.67476003244519},
#        {'lat': 1.309310020878911, 'lng': 103.67559000849724}],
#       'length': 93.0}]}},
#   'currentFlow': {'speed': 8.888889,
#    'speedUncapped': 8.888889,
#    'freeFlow': 12.5,
#    'jamFactor': 1.9,
#    'confidence': 0.76,
#    'traversability': 'open'}},
#  {'location': {'description': 'Jalan Kebun Limau',
#    'length': 457.0,
#    'shape': {'links': [{'points': [{'lat': 1.3168200384825468,
#         'lng': 103.85766003280878},
#        {'lat': 1.3171900156885386, 'lng': 103.85708997957408}],
#       'length': 75.0},
#      {'points': [{'lat': 1.3171900156885386, 'lng': 103.85708997957408},
#        {'lat': 1.3173399679362774, 'lng': 103.85681999847293}],
#       'length': 34.0},
#      {'points': [{'lat': 1.3173399679362774, 'lng': 103.85681999847293},
#        {'lat': 1.3175399601459503, 'lng': 103.85649000294507}],
#       'length': 43.0},
#      {'points': [{'lat': 1.3175399601459503, 'lng': 103.85649000294507},
#        {'lat': 1.3177599851042032, 'lng': 103.85612002573907}],
#       'length': 48.0},
#      {'points': [{'lat': 1.3177599851042032, 'lng': 103.85612002573907},
#        {'lat': 1.3181400205940008, 'lng': 103.85550999082625},
#        {'lat': 1.3183400128036737, 'lng': 103.85520002804697}],
#       'length': 121.0},
#      {'points': [{'lat': 1.3183400128036737, 'lng': 103.85520002804697},
#        {'lat': 1.3185300305485725, 'lng': 103.85488000698388}],
#       'length': 41.0},
#      {'points': [{'lat': 1.3185300305485725, 'lng': 103.85488000698388},
#        {'lat': 1.318609993904829, 'lng': 103.85474002920091}],
#       'length': 18.0},
#      {'points': [{'lat': 1.318609993904829, 'lng': 103.85474002920091},
#        {'lat': 1.3187399972230196, 'lng': 103.85454003699124}],
#       'length': 26.0},
#      {'points': [{'lat': 1.3187399972230196, 'lng': 103.85454003699124},
#        {'lat': 1.3189099822193384, 'lng': 103.8542500231415}],
#       'length': 37.0},
#      {'points': [{'lat': 1.3189099822193384, 'lng': 103.8542500231415},
#        {'lat': 1.3189799711108208, 'lng': 103.85413996875286}],
#       'length': 14.0}]}},
#   'currentFlow': {'speed': 9.166667,
#    'speedUncapped': 9.166667,
#    'freeFlow': 13.055556,
#    'jamFactor': 1.8,
#    'confidence': 0.99,
#    'traversability': 'open'}},
#  {'location': {'description': 'Jurong Town Hall Rd/Exit 13',
#    'length': 1734.0,
#    'shape': {'links': [{'points': [{'lat': 1.3186700083315372,
#         'lng': 103.75656003132463},
#        {'lat': 1.3190499600023031, 'lng': 103.75624001026154}],
#       'length': 55.0},
#      {'points': [{'lat': 1.3190499600023031, 'lng': 103.75624001026154},
#        {'lat': 1.3194399699568748, 'lng': 103.75591001473367}],
#       'length': 57.0},
#      {'points': [{'lat': 1.3194399699568748, 'lng': 103.75591001473367},
#        {'lat': 1.3197100348770618, 'lng': 103.75568001531065},
#        {'lat': 1.3199800159782171, 'lng': 103.75545001588762},
#        {'lat': 1.3202100154012442, 'lng': 103.75523996539414}],
#       'length': 113.0},
#      {'points': [{'lat': 1.3202100154012442, 'lng': 103.75523996539414},
#        {'lat': 1.3202899787575006, 'lng': 103.75516000203788},
#        {'lat': 1.3204599637538195, 'lng': 103.75499999150634},
#        {'lat': 1.3206199742853642, 'lng': 103.75482003204525},
#        {'lat': 1.3207499776035547, 'lng': 103.7546600215137}],
#       'length': 88.0},
#      {'points': [{'lat': 1.3207499776035547, 'lng': 103.7546600215137},
#        {'lat': 1.320839999243617, 'lng': 103.75453999266028},
#        {'lat': 1.3209399953484535, 'lng': 103.75437998212874},
#        {'lat': 1.3209900353103876, 'lng': 103.7542799860239}],
#       'length': 50.0},
#      {'points': [{'lat': 1.3209900353103876, 'lng': 103.7542799860239},
#        {'lat': 1.3210499659180641, 'lng': 103.75416004098952},
#        {'lat': 1.3211499620229006, 'lng': 103.75391998328269},
#        {'lat': 1.321290023624897, 'lng': 103.75352997332811},
#        {'lat': 1.3214399758726358, 'lng': 103.75306997448206}],
#       'length': 143.0},
#      {'points': [{'lat': 1.3214399758726358, 'lng': 103.75306997448206},
#        {'lat': 1.3215399719774723, 'lng': 103.75279001891613},
#        {'lat': 1.3216200191527605, 'lng': 103.75253998674452}],
#       'length': 62.0},
#      {'points': [{'lat': 1.3216200191527605, 'lng': 103.75253998674452},
#        {'lat': 1.321699982509017, 'lng': 103.75227000564337}],
#       'length': 31.0},
#      {'points': [{'lat': 1.321699982509017, 'lng': 103.75227000564337},
#        {'lat': 1.3217599969357252, 'lng': 103.75207998789847},
#        {'lat': 1.3218900002539158, 'lng': 103.75168000347912},
#        {'lat': 1.3219400402158499, 'lng': 103.75151999294758}],
#       'length': 87.0},
#      {'points': [{'lat': 1.3219400402158499, 'lng': 103.75151999294758},
#        {'lat': 1.322129974141717, 'lng': 103.75089998356998}],
#       'length': 72.0},
#      {'points': [{'lat': 1.322129974141717, 'lng': 103.75089998356998},
#        {'lat': 1.322159981355071, 'lng': 103.75079998746514},
#        {'lat': 1.3221899885684252, 'lng': 103.7506999913603}],
#       'length': 23.0},
#      {'points': [{'lat': 1.3221899885684252, 'lng': 103.7506999913603},
#        {'lat': 1.3222400285303593, 'lng': 103.75047996640205}],
#       'length': 25.0},
#      {'points': [{'lat': 1.3222400285303593, 'lng': 103.75047996640205},
#        {'lat': 1.3223499990999699, 'lng': 103.75006003305316}],
#       'length': 48.0},
#      {'points': [{'lat': 1.3223499990999699, 'lng': 103.75006003305316},
#        {'lat': 1.322400039061904, 'lng': 103.7498400080949}],
#       'length': 25.0},
#      {'points': [{'lat': 1.322400039061904, 'lng': 103.7498400080949},
#        {'lat': 1.3224599696695805, 'lng': 103.7495899759233}],
#       'length': 29.0},
#      {'points': [{'lat': 1.3224599696695805, 'lng': 103.7495899759233},
#        {'lat': 1.3225299585610628, 'lng': 103.74934002757072},
#        {'lat': 1.322579998522997, 'lng': 103.74906996265054}],
#       'length': 59.0},
#      {'points': [{'lat': 1.322579998522997, 'lng': 103.74906996265054},
#        {'lat': 1.3226499874144793, 'lng': 103.74873996712267}],
#       'length': 37.0},
#      {'points': [{'lat': 1.3226499874144793, 'lng': 103.74873996712267},
#        {'lat': 1.3229400012642145, 'lng': 103.74731998890638}],
#       'length': 161.0},
#      {'points': [{'lat': 1.3229400012642145, 'lng': 103.74731998890638},
#        {'lat': 1.3231700006872416, 'lng': 103.74630996957421},
#        {'lat': 1.323269996792078, 'lng': 103.74583999626338}],
#       'length': 168.0},
#      {'points': [{'lat': 1.323269996792078, 'lng': 103.74583999626338},
#        {'lat': 1.3233099784702063, 'lng': 103.74566003680229}],
#       'length': 20.0},
#      {'points': [{'lat': 1.3233099784702063, 'lng': 103.74566003680229},
#        {'lat': 1.3233399856835604, 'lng': 103.74554000794888},
#        {'lat': 1.3235099706798792, 'lng': 103.74471003189683}],
#       'length': 108.0},
#      {'points': [{'lat': 1.3235099706798792, 'lng': 103.74471003189683},
#        {'lat': 1.3235999923199415, 'lng': 103.7442900147289},
#        {'lat': 1.3236699812114239, 'lng': 103.74400997534394},
#        {'lat': 1.3237600028514862, 'lng': 103.74373001977801},
#        {'lat': 1.3238399662077427, 'lng': 103.74353002756834}],
#       'length': 136.0},
#      {'points': [{'lat': 1.3238399662077427, 'lng': 103.74353002756834},
#        {'lat': 1.3239100389182568, 'lng': 103.7433700170368},
#        {'lat': 1.3239699695259333, 'lng': 103.7432400137186}],
#       'length': 35.0},
#      {'points': [{'lat': 1.3239699695259333, 'lng': 103.7432400137186},
#        {'lat': 1.3240299839526415, 'lng': 103.74311001040041},
#        {'lat': 1.324150012806058, 'lng': 103.74291001819074},
#        {'lat': 1.3242800161242485, 'lng': 103.74268999323249},
#        {'lat': 1.3244199939072132, 'lng': 103.74243996106088}],
#       'length': 102.0}]}},
#   'currentFlow': {'speed': 21.38889,
#    'speedUncapped': 21.38889,
#    'freeFlow': 20.833334,
#    'jamFactor': 0.0,
#    'confidence': 0.99,
#    'traversability': 'open'}},
#  {'location': {'description': 'Syed Alwi Rd',
#    'length': 35.0,
#    'shape': {'links': [{'points': [{'lat': 1.3068400416523218,
#         'lng': 103.85872998274863},
#        {'lat': 1.30688002333045, 'lng': 103.85872998274863},
#        {'lat': 1.3069200050085783, 'lng': 103.85875001549721},
#        {'lat': 1.307080015540123, 'lng': 103.85892000049353}],
#       'length': 35.0}]}},
#   'currentFlow': {'speed': 5.277778,
#    'speedUncapped': 5.277778,
#    'freeFlow': 7.777778,
#    'jamFactor': 1.7,
#    'confidence': 0.84,
#    'traversability': 'open'}},
#  {'location': {'description': 'Havelock Rd/Upp Cross St',
#    'length': 627.0,
#    'shape': {'links': [{'points': [{'lat': 1.2929600290954113,
#         'lng': 103.84374003857374},
#        {'lat': 1.2927000224590302, 'lng': 103.84359000250697},
#        {'lat': 1.2920400314033031, 'lng': 103.84322002530098},
#        {'lat': 1.2915399670600891, 'lng': 103.84293998591602}],
#       'length': 181.0},
#      {'points': [{'lat': 1.2915399670600891, 'lng': 103.84293998591602},
#        {'lat': 1.291330000385642, 'lng': 103.84283001534641}],
#       'length': 26.0},
#      {'points': [{'lat': 1.291330000385642, 'lng': 103.84283001534641},
#        {'lat': 1.291120033711195, 'lng': 103.84271996095777}],
#       'length': 26.0},
#      {'points': [{'lat': 1.291120033711195, 'lng': 103.84271996095777},
#        {'lat': 1.2910200376063585, 'lng': 103.84266003035009}],
#       'length': 13.0},
#      {'points': [{'lat': 1.2910200376063585, 'lng': 103.84266003035009},
#        {'lat': 1.2909099832177162, 'lng': 103.84260999038815}],
#       'length': 13.0},
#      {'points': [{'lat': 1.2909099832177162, 'lng': 103.84260999038815},
#        {'lat': 1.2905799876898527, 'lng': 103.84240999817848}],
#       'length': 43.0},
#      {'points': [{'lat': 1.2905799876898527, 'lng': 103.84240999817848},
#        {'lat': 1.2905199732631445, 'lng': 103.84237999096513}],
#       'length': 7.0},
#      {'points': [{'lat': 1.2905199732631445, 'lng': 103.84237999096513},
#        {'lat': 1.2903599627315998, 'lng': 103.84230002760887}],
#       'length': 20.0},
#      {'points': [{'lat': 1.2903599627315998, 'lng': 103.84230002760887},
#        {'lat': 1.2903100065886974, 'lng': 103.84227002039552}],
#       'length': 6.0},
#      {'points': [{'lat': 1.2903100065886974, 'lng': 103.84227002039552},
#        {'lat': 1.290219984948635, 'lng': 103.84221998043358}],
#       'length': 11.0},
#      {'points': [{'lat': 1.290219984948635, 'lng': 103.84221998043358},
#        {'lat': 1.2901299633085728, 'lng': 103.84217999875546}],
#       'length': 11.0},
#      {'points': [{'lat': 1.2901299633085728, 'lng': 103.84217999875546},
#        {'lat': 1.290010018274188, 'lng': 103.84212995879352}],
#       'length': 14.0},
#      {'points': [{'lat': 1.290010018274188, 'lng': 103.84212995879352},
#        {'lat': 1.289750011637807, 'lng': 103.84200003929436}],
#       'length': 32.0},
#      {'points': [{'lat': 1.289750011637807, 'lng': 103.84200003929436},
#        {'lat': 1.2892900127917528, 'lng': 103.84175998158753}],
#       'length': 58.0},
#      {'points': [{'lat': 1.2892900127917528, 'lng': 103.84175998158753},
#        {'lat': 1.289079962298274, 'lng': 103.84168001823127}],
#       'length': 25.0},
#      {'points': [{'lat': 1.289079962298274, 'lng': 103.84168001823127},
#        {'lat': 1.2889300100505352, 'lng': 103.84162000380456}],
#       'length': 18.0},
#      {'points': [{'lat': 1.2889300100505352, 'lng': 103.84162000380456},
#        {'lat': 1.2887000106275082, 'lng': 103.8415299821645}],
#       'length': 27.0},
#      {'points': [{'lat': 1.2887000106275082, 'lng': 103.8415299821645},
#        {'lat': 1.2885300256311893, 'lng': 103.84145999327302}],
#       'length': 20.0},
#      {'points': [{'lat': 1.2885300256311893, 'lng': 103.84145999327302},
#        {'lat': 1.288240011781454, 'lng': 103.8412900082767}],
#       'length': 37.0},
#      {'points': [{'lat': 1.288240011781454, 'lng': 103.8412900082767},
#        {'lat': 1.2879499979317188, 'lng': 103.84109001606703}],
#       'length': 39.0}]}},
#   'currentFlow': {'speed': 5.8333335,
#    'speedUncapped': 5.8333335,
#    'freeFlow': 11.111112,
#    'jamFactor': 4.0,
#    'confidence': 0.99,
#    'traversability': 'open',
#    'subSegments': [{'length': 357.0,
#      'speed': 9.166667,
#      'speedUncapped': 9.166667,
#      'freeFlow': 12.777778,
#      'jamFactor': 2.4,
#      'confidence': 0.99,
#      'traversability': 'open'},
#     {'length': 270.0,
#      'speed': 3.888889,
#      'speedUncapped': 3.888889,
#      'freeFlow': 9.722222,
#      'jamFactor': 5.1,
#      'confidence': 0.99,
#      'traversability': 'open'}]}},
#  {'location': {'description': 'Tessensohn Rd/Race Course Rd',
#    'length': 22.0,
#    'shape': {'links': [{'points': [{'lat': 1.3136199954897165,
#         'lng': 103.85439997538924},
#        {'lat': 1.3134400360286236, 'lng': 103.8544899970293}],
#       'length': 22.0}]}},
#   'currentFlow': {'speed': 6.388889,
#    'speedUncapped': 6.388889,
#    'freeFlow': 8.333334,
#    'jamFactor': 1.0,
#    'confidence': 0.91,
#    'traversability': 'open'}},
#  {'location': {'description': 'Tg Rhu Rd/Meyer Rd',
#    'length': 297.0,
#    'shape': {'links': [{'points': [{'lat': 1.30065000616014,
#         'lng': 103.88557998463511},
#        {'lat': 1.3000200223177671, 'lng': 103.88554000295699}],
#       'length': 70.0},
#      {'points': [{'lat': 1.3000200223177671, 'lng': 103.88554000295699},
#        {'lat': 1.2993900384753942, 'lng': 103.88550002127886}],
#       'length': 70.0},
#      {'points': [{'lat': 1.2993900384753942, 'lng': 103.88550002127886},
#        {'lat': 1.2990300357341766, 'lng': 103.88547998853028}],
#       'length': 40.0},
#      {'points': [{'lat': 1.2990300357341766, 'lng': 103.88547998853028},
#        {'lat': 1.2987499963492155, 'lng': 103.8854700140655}],
#       'length': 31.0},
#      {'points': [{'lat': 1.2987499963492155, 'lng': 103.8854700140655},
#        {'lat': 1.2985400296747684, 'lng': 103.88546003960073}],
#       'length': 23.0},
#      {'points': [{'lat': 1.2985400296747684, 'lng': 103.88546003960073},
#        {'lat': 1.2983400374650955, 'lng': 103.88544998131692}],
#       'length': 22.0},
#      {'points': [{'lat': 1.2983400374650955, 'lng': 103.88544998131692},
#        {'lat': 1.2980399653315544, 'lng': 103.88543003238738}],
#       'length': 33.0},
#      {'points': [{'lat': 1.2980399653315544, 'lng': 103.88543003238738},
#        {'lat': 1.297969976440072, 'lng': 103.88543003238738}],
#       'length': 8.0}]}},
#   'currentFlow': {'speed': 5.0,
#    'speedUncapped': 5.0,
#    'freeFlow': 8.888889,
#    'jamFactor': 3.0,
#    'confidence': 0.99,
#    'traversability': 'open'}},
#  {'location': {'description': 'Pioneer Sector 2',
#    'length': 514.0,
#    'shape': {'links': [{'points': [{'lat': 1.2987700290977955,
#         'lng': 103.66794998757541},
#        {'lat': 1.2989300396293402, 'lng': 103.6678400170058},
#        {'lat': 1.3000399712473154, 'lng': 103.66728999651968}],
#       'length': 159.0},
#      {'points': [{'lat': 1.3000399712473154, 'lng': 103.66728999651968},
#        {'lat': 1.300169974565506, 'lng': 103.66724004037678}],
#       'length': 15.0},
#      {'points': [{'lat': 1.300169974565506, 'lng': 103.66724004037678},
#        {'lat': 1.300450013950467, 'lng': 103.66711003705859}],
#       'length': 34.0},
#      {'points': [{'lat': 1.300450013950467, 'lng': 103.66711003705859},
#        {'lat': 1.3007999584078789, 'lng': 103.66695002652705}],
#       'length': 43.0},
#      {'points': [{'lat': 1.3007999584078789, 'lng': 103.66695002652705},
#        {'lat': 1.3010700233280659, 'lng': 103.66682002320886}],
#       'length': 33.0},
#      {'points': [{'lat': 1.3010700233280659, 'lng': 103.66682002320886},
#        {'lat': 1.30153002217412, 'lng': 103.66662003099918}],
#       'length': 56.0},
#      {'points': [{'lat': 1.30153002217412, 'lng': 103.66662003099918},
#        {'lat': 1.3026800192892551, 'lng': 103.66604000329971},
#        {'lat': 1.3029299676418304, 'lng': 103.66590999998152}],
#       'length': 174.0}]}},
#   'currentFlow': {'speed': 13.888889,
#    'speedUncapped': 14.722222,
#    'freeFlow': 11.111112,
#    'jamFactor': 0.0,
#    'confidence': 0.81,
#    'traversability': 'open'}},
#  {'location': {'description': 'Tuas South Ave 3',
#    'length': 470.0,
#    'shape': {'links': [{'points': [{'lat': 1.2850399687886238,
#         'lng': 103.63078001886606},
#        {'lat': 1.2883799895644188, 'lng': 103.63101001828909}],
#       'length': 372.0},
#      {'points': [{'lat': 1.2883799895644188, 'lng': 103.63101001828909},
#        {'lat': 1.288649970665574, 'lng': 103.63102996721864}],
#       'length': 30.0},
#      {'points': [{'lat': 1.288649970665574, 'lng': 103.63102996721864},
#        {'lat': 1.288869995623827, 'lng': 103.63104999996722}],
#       'length': 25.0},
#      {'points': [{'lat': 1.288869995623827, 'lng': 103.63104999996722},
#        {'lat': 1.2890099734067917, 'lng': 103.63105997443199}],
#       'length': 16.0},
#      {'points': [{'lat': 1.2890099734067917, 'lng': 103.63105997443199},
#        {'lat': 1.2892500311136246, 'lng': 103.63108000718057}],
#       'length': 27.0}]}},
#   'currentFlow': {'speed': 8.055555,
#    'speedUncapped': 8.055555,
#    'freeFlow': 10.555556,
#    'jamFactor': 1.4,
#    'confidence': 0.78,
#    'traversability': 'open'}},
#  {'location': {'description': 'Tuas South Ave 9',
#    'length': 449.0,
#    'shape': {'links': [{'points': [{'lat': 1.2929900363087654,
#         'lng': 103.64079999737442},
#        {'lat': 1.2932600174099207, 'lng': 103.6400599591434}],
#       'length': 87.0},
#      {'points': [{'lat': 1.2932600174099207, 'lng': 103.6400599591434},
#        {'lat': 1.2937999796122313, 'lng': 103.63856999203563}],
#       'length': 176.0},
#      {'points': [{'lat': 1.2937999796122313, 'lng': 103.63856999203563},
#        {'lat': 1.2938800267875195, 'lng': 103.6383399926126}],
#       'length': 27.0},
#      {'points': [{'lat': 1.2938800267875195, 'lng': 103.6383399926126},
#        {'lat': 1.29396996460855, 'lng': 103.6381000187248},
#        {'lat': 1.29401003010571, 'lng': 103.63798996433616}],
#       'length': 41.0},
#      {'points': [{'lat': 1.29401003010571, 'lng': 103.63798996433616},
#        {'lat': 1.2941400334239006, 'lng': 103.63764999434352}],
#       'length': 40.0},
#      {'points': [{'lat': 1.2941400334239006, 'lng': 103.63764999434352},
#        {'lat': 1.2942599784582853, 'lng': 103.63732997328043}],
#       'length': 38.0},
#      {'points': [{'lat': 1.2942599784582853, 'lng': 103.63732997328043},
#        {'lat': 1.294240029528737, 'lng': 103.63725000992417},
#        {'lat': 1.294240029528737, 'lng': 103.63716996274889}],
#       'length': 18.0},
#      {'points': [{'lat': 1.294240029528737, 'lng': 103.63716996274889},
#        {'lat': 1.2942999601364136, 'lng': 103.63698002882302}],
#       'length': 22.0}]}},
#   'currentFlow': {'speed': 9.444445,
#    'speedUncapped': 9.444445,
#    'freeFlow': 10.0,
#    'jamFactor': 0.4,
#    'confidence': 0.7,
#    'traversability': 'open'}},
#  {'location': {'description': 'Thomson Rd/Exit 17/Exit 17D',
#    'length': 974.0,
#    'shape': {'links': [{'points': [{'lat': 1.3265400286763906,
#         'lng': 103.83476997725666},
#        {'lat': 1.3265500031411648, 'lng': 103.83482001721859}],
#       'length': 6.0},
#      {'points': [{'lat': 1.3265500031411648, 'lng': 103.83482001721859},
#        {'lat': 1.3265700358897448, 'lng': 103.83489998057485}],
#       'length': 9.0},
#      {'points': [{'lat': 1.3265700358897448, 'lng': 103.83489998057485},
#        {'lat': 1.326610017567873, 'lng': 103.83499997667968}],
#       'length': 12.0},
#      {'points': [{'lat': 1.326610017567873, 'lng': 103.83499997667968},
#        {'lat': 1.3266499992460012, 'lng': 103.83512997999787}],
#       'length': 15.0},
#      {'points': [{'lat': 1.3266499992460012, 'lng': 103.83512997999787},
#        {'lat': 1.3268299587070942, 'lng': 103.83570003323257}],
#       'length': 66.0},
#      {'points': [{'lat': 1.3268299587070942, 'lng': 103.83570003323257},
#        {'lat': 1.3269599620252848, 'lng': 103.83610001765192}],
#       'length': 47.0},
#      {'points': [{'lat': 1.3269599620252848, 'lng': 103.83610001765192},
#        {'lat': 1.3271099980920553, 'lng': 103.83656001649797}],
#       'length': 54.0},
#      {'points': [{'lat': 1.3271099980920553, 'lng': 103.83656001649797},
#        {'lat': 1.3271799869835377, 'lng': 103.83678004145622},
#        {'lat': 1.327240001410246, 'lng': 103.83699000813067}],
#       'length': 50.0},
#      {'points': [{'lat': 1.327240001410246, 'lng': 103.83699000813067},
#        {'lat': 1.3273000158369541, 'lng': 103.83721003308892},
#        {'lat': 1.3274600263684988, 'lng': 103.83767003193498}],
#       'length': 79.0},
#      {'points': [{'lat': 1.3274600263684988, 'lng': 103.83767003193498},
#        {'lat': 1.3275600224733353, 'lng': 103.83794001303613},
#        {'lat': 1.3276900257915258, 'lng': 103.83824000135064},
#        {'lat': 1.3278399780392647, 'lng': 103.83854996412992}],
#       'length': 106.0},
#      {'points': [{'lat': 1.3278399780392647, 'lng': 103.83854996412992},
#        {'lat': 1.3280399702489376, 'lng': 103.83889999240637}],
#       'length': 45.0},
#      {'points': [{'lat': 1.3280399702489376, 'lng': 103.83889999240637},
#        {'lat': 1.3284699618816376, 'lng': 103.83962997235358},
#        {'lat': 1.3287700340151787, 'lng': 103.84014001116157}],
#       'length': 160.0},
#      {'points': [{'lat': 1.3287700340151787, 'lng': 103.84014001116157},
#        {'lat': 1.3288499973714352, 'lng': 103.84027998894453},
#        {'lat': 1.3289599679410458, 'lng': 103.8404799811542},
#        {'lat': 1.3291599601507187, 'lng': 103.84089002385736},
#        {'lat': 1.3293099962174892, 'lng': 103.84122001938522},
#        {'lat': 1.3294199667870998, 'lng': 103.84152000769973},
#        {'lat': 1.329500013962388, 'lng': 103.84181999601424}],
#       'length': 204.0},
#      {'points': [{'lat': 1.329500013962388, 'lng': 103.84181999601424},
#        {'lat': 1.3295799773186445, 'lng': 103.84215996600688},
#        {'lat': 1.3296399917453527, 'lng': 103.84256003424525},
#        {'lat': 1.3296699989587069, 'lng': 103.84290000423789}],
#       'length': 121.0}]}},
#   'currentFlow': {'speed': 22.222223,
#    'speedUncapped': 22.777779,
#    'freeFlow': 22.222223,
#    'jamFactor': 0.0,
#    'confidence': 0.99,
#    'traversability': 'open'}},
#  {'location': {'description': 'Whitley Rd',
#    'length': 521.0,
#    'shape': {'links': [{'points': [{'lat': 1.3267400208860636,
#         'lng': 103.83033997379243},
#        {'lat': 1.326610017567873, 'lng': 103.83061003871262},
#        {'lat': 1.3264400325715542, 'lng': 103.8309200014919}],
#       'length': 72.0},
#      {'points': [{'lat': 1.3264400325715542, 'lng': 103.8309200014919},
#        {'lat': 1.3262999709695578, 'lng': 103.83117003366351}],
#       'length': 32.0},
#      {'points': [{'lat': 1.3262999709695578, 'lng': 103.83117003366351},
#        {'lat': 1.3261999748647213, 'lng': 103.83134001865983}],
#       'length': 22.0},
#      {'points': [{'lat': 1.3261999748647213, 'lng': 103.83134001865983},
#        {'lat': 1.3260999787598848, 'lng': 103.83155995979905},
#        {'lat': 1.3260399643331766, 'lng': 103.8317199703306}],
#       'length': 46.0},
#      {'points': [{'lat': 1.3260399643331766, 'lng': 103.8317199703306},
#        {'lat': 1.325950026512146, 'lng': 103.83207997307181}],
#       'length': 41.0},
#      {'points': [{'lat': 1.325950026512146, 'lng': 103.83207997307181},
#        {'lat': 1.3259200192987919, 'lng': 103.83230997249484},
#        {'lat': 1.3259200192987919, 'lng': 103.83262001909316},
#        {'lat': 1.3259699754416943, 'lng': 103.83295001462102}],
#       'length': 97.0},
#      {'points': [{'lat': 1.3259699754416943, 'lng': 103.83295001462102},
#        {'lat': 1.3260299898684025, 'lng': 103.8331999629736},
#        {'lat': 1.326139960438013, 'lng': 103.83354999125004},
#        {'lat': 1.3262800220400095, 'lng': 103.83399004116654}],
#       'length': 120.0},
#      {'points': [{'lat': 1.3262800220400095, 'lng': 103.83399004116654},
#        {'lat': 1.3263999670743942, 'lng': 103.83433998562396},
#        {'lat': 1.3264299742877483, 'lng': 103.83443998172879},
#        {'lat': 1.3265400286763906, 'lng': 103.83476997725666}],
#       'length': 91.0}]}},
#   'currentFlow': {'speed': 22.222223,
#    'speedUncapped': 22.777779,
#    'freeFlow': 21.38889,
#    'jamFactor': 0.0,
#    'confidence': 0.99,
#    'traversability': 'open'}},
#  {'location': {'description': 'Tampines Ave 1',
#    'length': 460.0,
#    'shape': {'links': [{'points': [{'lat': 1.348779983818531,
#         'lng': 103.93823996186256},
#        {'lat': 1.348570017144084, 'lng': 103.93826996907592},
#        {'lat': 1.348370024934411, 'lng': 103.93829997628927}],
#       'length': 46.0},
#      {'points': [{'lat': 1.348370024934411, 'lng': 103.93829997628927},
#        {'lat': 1.3481899816542864, 'lng': 103.93832000903785}],
#       'length': 20.0},
#      {'points': [{'lat': 1.3481899816542864, 'lng': 103.93832000903785},
#        {'lat': 1.3480199966579676, 'lng': 103.93834004178643},
#        {'lat': 1.3478500116616488, 'lng': 103.93835999071598}],
#       'length': 38.0},
#      {'points': [{'lat': 1.3478500116616488, 'lng': 103.93835999071598},
#        {'lat': 1.3476200122386217, 'lng': 103.93836996518075},
#        {'lat': 1.3474699761718512, 'lng': 103.93838002346456}],
#       'length': 42.0},
#      {'points': [{'lat': 1.3474699761718512, 'lng': 103.93838002346456},
#        {'lat': 1.3471699878573418, 'lng': 103.93839997239411},
#        {'lat': 1.3469000067561865, 'lng': 103.93842000514269},
#        {'lat': 1.3466400001198053, 'lng': 103.93845001235604}],
#       'length': 93.0},
#      {'points': [{'lat': 1.3466400001198053, 'lng': 103.93845001235604},
#        {'lat': 1.346600018441677, 'lng': 103.93845001235604}],
#       'length': 4.0},
#      {'points': [{'lat': 1.346600018441677, 'lng': 103.93845001235604},
#        {'lat': 1.3460599724203348, 'lng': 103.93844003789127}],
#       'length': 60.0},
#      {'points': [{'lat': 1.3460599724203348, 'lng': 103.93844003789127},
#        {'lat': 1.3458400312811136, 'lng': 103.93844003789127}],
#       'length': 24.0},
#      {'points': [{'lat': 1.3458400312811136, 'lng': 103.93844003789127},
#        {'lat': 1.3456999696791172, 'lng': 103.93842997960746}],
#       'length': 16.0},
#      {'points': [{'lat': 1.3456999696791172, 'lng': 103.93842997960746},
#        {'lat': 1.3453599996864796, 'lng': 103.93842000514269}],
#       'length': 38.0},
#      {'points': [{'lat': 1.3453599996864796, 'lng': 103.93842000514269},
#        {'lat': 1.3451300002634525, 'lng': 103.93841003067791}],
#       'length': 26.0},
#      {'points': [{'lat': 1.3451300002634525, 'lng': 103.93841003067791},
#        {'lat': 1.344800004735589, 'lng': 103.93838999792933}],
#       'length': 37.0},
#      {'points': [{'lat': 1.344800004735589, 'lng': 103.93838999792933},
#        {'lat': 1.3446600269526243, 'lng': 103.93838999792933}],
#       'length': 16.0}]}},
#   'currentFlow': {'speed': 5.277778,
#    'speedUncapped': 5.277778,
#    'freeFlow': 8.055555,
#    'jamFactor': 2.0,
#    'confidence': 0.98,
#    'traversability': 'open'}},
#  {'location': {'description': 'Dunearn Rd/Bukit Timah Rd',
#    'length': 596.0,
#    'shape': {'links': [{'points': [{'lat': 1.3275099825114012,
#         'lng': 103.82068997249007},
#        {'lat': 1.3274300191551447, 'lng': 103.82068997249007},
#        {'lat': 1.3273300230503082, 'lng': 103.8206799980253}],
#       'length': 20.0},
#      {'points': [{'lat': 1.3273300230503082, 'lng': 103.8206799980253},
#        {'lat': 1.3270899653434753, 'lng': 103.82064999081194}],
#       'length': 27.0},
#      {'points': [{'lat': 1.3270899653434753, 'lng': 103.82064999081194},
#        {'lat': 1.3266599737107754, 'lng': 103.82060003466904}],
#       'length': 48.0},
#      {'points': [{'lat': 1.3266599737107754, 'lng': 103.82060003466904},
#        {'lat': 1.3265299703925848, 'lng': 103.82058000192046}],
#       'length': 15.0},
#      {'points': [{'lat': 1.3265299703925848, 'lng': 103.82058000192046},
#        {'lat': 1.3262999709695578, 'lng': 103.82054999470711}],
#       'length': 26.0},
#      {'points': [{'lat': 1.3262999709695578, 'lng': 103.82054999470711},
#        {'lat': 1.325750034302473, 'lng': 103.82047003135085},
#        {'lat': 1.3256699871271849, 'lng': 103.82045997306705}],
#       'length': 71.0},
#      {'points': [{'lat': 1.3256699871271849, 'lng': 103.82045997306705},
#        {'lat': 1.325479969382286, 'lng': 103.82042996585369},
#        {'lat': 1.3248599600046873, 'lng': 103.82032996974885}],
#       'length': 91.0},
#      {'points': [{'lat': 1.3248599600046873, 'lng': 103.82032996974885},
#        {'lat': 1.3246800005435944, 'lng': 103.8202999625355}],
#       'length': 20.0},
#      {'points': [{'lat': 1.3246800005435944, 'lng': 103.8202999625355},
#        {'lat': 1.3244599755853415, 'lng': 103.82025998085737},
#        {'lat': 1.324410019442439, 'lng': 103.8202500063926}],
#       'length': 31.0},
#      {'points': [{'lat': 1.324410019442439, 'lng': 103.8202500063926},
#        {'lat': 1.3242200016975403, 'lng': 103.82021002471447}],
#       'length': 22.0},
#      {'points': [{'lat': 1.3242200016975403, 'lng': 103.82021002471447},
#        {'lat': 1.3241100311279297, 'lng': 103.82018999196589}],
#       'length': 12.0},
#      {'points': [{'lat': 1.3241100311279297, 'lng': 103.82018999196589},
#        {'lat': 1.323499996215105, 'lng': 103.8200599886477}],
#       'length': 69.0},
#      {'points': [{'lat': 1.323499996215105, 'lng': 103.8200599886477},
#        {'lat': 1.3232200406491756, 'lng': 103.81999997422099}],
#       'length': 32.0},
#      {'points': [{'lat': 1.3232200406491756, 'lng': 103.81999997422099},
#        {'lat': 1.322789965197444, 'lng': 103.81991003639996}],
#       'length': 49.0},
#      {'points': [{'lat': 1.322789965197444, 'lng': 103.81991003639996},
#        {'lat': 1.3227100018411875, 'lng': 103.81989000365138}],
#       'length': 9.0},
#      {'points': [{'lat': 1.3227100018411875, 'lng': 103.81989000365138},
#        {'lat': 1.322610005736351, 'lng': 103.81991003639996},
#        {'lat': 1.3225000351667404, 'lng': 103.81989000365138},
#        {'lat': 1.3222800102084875, 'lng': 103.81983996368945},
#        {'lat': 1.3222299702465534, 'lng': 103.81982998922467}],
#       'length': 54.0}]}},
#   'currentFlow': {'speed': 4.166667,
#    'speedUncapped': 4.166667,
#    'freeFlow': 7.2222223,
#    'jamFactor': 2.5,
#    'confidence': 0.71,
#    'traversability': 'open'}},
#  {'location': {'description': 'Sengkang East Way',
#    'length': 301.0,
#    'shape': {'links': [{'points': [{'lat': 1.3956400193274021,
#         'lng': 103.89453001320362},
#        {'lat': 1.3953500054776669, 'lng': 103.89443001709878}],
#       'length': 34.0},
#      {'points': [{'lat': 1.3953500054776669, 'lng': 103.89443001709878},
#        {'lat': 1.3950399588793516, 'lng': 103.89431996271014}],
#       'length': 37.0},
#      {'points': [{'lat': 1.3950399588793516, 'lng': 103.89431996271014},
#        {'lat': 1.394950021058321, 'lng': 103.89429003931582}],
#       'length': 11.0},
#      {'points': [{'lat': 1.394950021058321, 'lng': 103.89429003931582},
#        {'lat': 1.3946099672466516, 'lng': 103.8941700104624}],
#       'length': 40.0},
#      {'points': [{'lat': 1.3946099672466516, 'lng': 103.8941700104624},
#        {'lat': 1.3942099828273058, 'lng': 103.89403003267944}],
#       'length': 47.0},
#      {'points': [{'lat': 1.3942099828273058, 'lng': 103.89403003267944},
#        {'lat': 1.3939099945127964, 'lng': 103.8939300365746}],
#       'length': 35.0},
#      {'points': [{'lat': 1.3939099945127964, 'lng': 103.8939300365746},
#        {'lat': 1.3935700245201588, 'lng': 103.89381000772119}],
#       'length': 40.0},
#      {'points': [{'lat': 1.3935700245201588, 'lng': 103.89381000772119},
#        {'lat': 1.3935400173068047, 'lng': 103.89380003325641}],
#       'length': 4.0},
#      {'points': [{'lat': 1.3935400173068047, 'lng': 103.89380003325641},
#        {'lat': 1.3933700323104858, 'lng': 103.8937400188297}],
#       'length': 20.0},
#      {'points': [{'lat': 1.3933700323104858, 'lng': 103.8937400188297},
#        {'lat': 1.3932500034570694, 'lng': 103.89370003715158}],
#       'length': 14.0},
#      {'points': [{'lat': 1.3932500034570694, 'lng': 103.89370003715158},
#        {'lat': 1.3930899929255247, 'lng': 103.89364999718964}],
#       'length': 19.0}]}},
#   'currentFlow': {'speed': 3.0555556,
#    'speedUncapped': 3.0555556,
#    'freeFlow': 9.166667,
#    'jamFactor': 5.9,
#    'confidence': 0.99,
#    'traversability': 'open'}},
#  {'location': {'description': 'Yio Chu Kang Rd',
#    'length': 63.0,
#    'shape': {'links': [{'points': [{'lat': 1.3750399835407734,
#         'lng': 103.87673003599048},
#        {'lat': 1.3750399835407734, 'lng': 103.87680002488196}],
#       'length': 8.0},
#      {'points': [{'lat': 1.3750399835407734, 'lng': 103.87680002488196},
#        {'lat': 1.3750300090759993, 'lng': 103.8769600354135}],
#       'length': 18.0},
#      {'points': [{'lat': 1.3750300090759993, 'lng': 103.8769600354135},
#        {'lat': 1.3750399835407734, 'lng': 103.8770099915564},
#        {'lat': 1.3750500418245792, 'lng': 103.87710001319647}],
#       'length': 16.0},
#      {'points': [{'lat': 1.3750500418245792, 'lng': 103.87710001319647},
#        {'lat': 1.3750600162893534, 'lng': 103.87720998376608},
#        {'lat': 1.3750600162893534, 'lng': 103.87729003094137}],
#       'length': 21.0}]}},
#   'currentFlow': {'speed': 5.555556,
#    'speedUncapped': 5.555556,
#    'freeFlow': 6.666667,
#    'jamFactor': 0.5,
#    'confidence': 0.92,
#    'traversability': 'open'}},
#  {'location': {'description': 'Punggol Rd',
#    'length': 374.0,
#    'shape': {'links': [{'points': [{'lat': 1.391809992492199,
#         'lng': 103.89827001839876},
#        {'lat': 1.3915700186043978, 'lng': 103.89896001666784}],
#       'length': 81.0},
#      {'points': [{'lat': 1.3915700186043978, 'lng': 103.89896001666784},
#        {'lat': 1.3914499897509813, 'lng': 103.89932001940906}],
#       'length': 42.0},
#      {'points': [{'lat': 1.3914499897509813, 'lng': 103.89932001940906},
#        {'lat': 1.3913499936461449, 'lng': 103.89956996776164},
#        {'lat': 1.3913199864327908, 'lng': 103.89965001493692}],
#       'length': 39.0},
#      {'points': [{'lat': 1.3913199864327908, 'lng': 103.89965001493692},
#        {'lat': 1.3912299647927284, 'lng': 103.89995997771621}],
#       'length': 36.0},
#      {'points': [{'lat': 1.3912299647927284, 'lng': 103.89995997771621},
#        {'lat': 1.391159975901246, 'lng': 103.90025996603072}],
#       'length': 34.0},
#      {'points': [{'lat': 1.391159975901246, 'lng': 103.90025996603072},
#        {'lat': 1.391129968687892, 'lng': 103.9005199726671}],
#       'length': 29.0},
#      {'points': [{'lat': 1.391129968687892, 'lng': 103.9005199726671},
#        {'lat': 1.3911100197583437, 'lng': 103.90084996819496}],
#       'length': 37.0},
#      {'points': [{'lat': 1.3911100197583437, 'lng': 103.90084996819496},
#        {'lat': 1.3910999614745378, 'lng': 103.9011399820447}],
#       'length': 32.0},
#      {'points': [{'lat': 1.3910999614745378, 'lng': 103.9011399820447},
#        {'lat': 1.3910999614745378, 'lng': 103.90142002142966}],
#       'length': 31.0},
#      {'points': [{'lat': 1.3910999614745378, 'lng': 103.90142002142966},
#        {'lat': 1.3910999614745378, 'lng': 103.90145002864301}],
#       'length': 3.0},
#      {'points': [{'lat': 1.3910999614745378, 'lng': 103.90145002864301},
#        {'lat': 1.3910999614745378, 'lng': 103.90153996646404}],
#       'length': 10.0}]}},
#   'currentFlow': {'speed': 6.9444447,
#    'speedUncapped': 6.9444447,
#    'freeFlow': 10.555556,
#    'jamFactor': 2.8,
#    'confidence': 0.95,
#    'traversability': 'open',
#    'subSegments': [{'length': 162.0,
#      'speed': 6.388889,
#      'speedUncapped': 6.388889,
#      'freeFlow': 13.055556,
#      'jamFactor': 4.7,
#      'confidence': 0.95,
#      'traversability': 'open'},
#     {'length': 212.0,
#      'speed': 7.777778,
#      'speedUncapped': 7.777778,
#      'freeFlow': 9.166667,
#      'jamFactor': 1.4,
#      'confidence': 0.95,
#      'traversability': 'open'}]}},
#  {'location': {'description': 'Neo Tiew Rd',
#    'length': 2575.0,
#    'shape': {'links': [{'points': [{'lat': 1.3998800050467253,
#         'lng': 103.69997003115714},
#        {'lat': 1.400219975039363, 'lng': 103.70002996176481}],
#       'length': 38.0},
#      {'points': [{'lat': 1.400219975039363, 'lng': 103.70002996176481},
#        {'lat': 1.4006000105291605, 'lng': 103.70010003447533},
#        {'lat': 1.4008200354874134, 'lng': 103.70014001615345}],
#       'length': 68.0},
#      {'points': [{'lat': 1.4008200354874134, 'lng': 103.70014001615345},
#        {'lat': 1.4010600093752146, 'lng': 103.70018997229636},
#        {'lat': 1.4012399688363075, 'lng': 103.70023003779352},
#        {'lat': 1.4014299865812063, 'lng': 103.70027999393642}],
#       'length': 70.0},
#      {'points': [{'lat': 1.4014299865812063, 'lng': 103.70027999393642},
#        {'lat': 1.4015999715775251, 'lng': 103.70033003389835}],
#       'length': 20.0},
#      {'points': [{'lat': 1.4015999715775251, 'lng': 103.70033003389835},
#        {'lat': 1.401789989322424, 'lng': 103.70040002278984},
#        {'lat': 1.4019400253891945, 'lng': 103.70046003721654},
#        {'lat': 1.4021000359207392, 'lng': 103.70053002610803},
#        {'lat': 1.402219980955124, 'lng': 103.70059004053473},
#        {'lat': 1.4023799914866686, 'lng': 103.70069003663957}],
#       'length': 96.0},
#      {'points': [{'lat': 1.4023799914866686, 'lng': 103.70069003663957},
#        {'lat': 1.4029399864375591, 'lng': 103.70097996667027}],
#       'length': 70.0},
#      {'points': [{'lat': 1.4029399864375591, 'lng': 103.70097996667027},
#        {'lat': 1.403150036931038, 'lng': 103.70109002105892}],
#       'length': 26.0},
#      {'points': [{'lat': 1.403150036931038, 'lng': 103.70109002105892},
#        {'lat': 1.4037400390952826, 'lng': 103.7013999838382}],
#       'length': 74.0},
#      {'points': [{'lat': 1.4037400390952826, 'lng': 103.7013999838382},
#        {'lat': 1.4038299769163132, 'lng': 103.70145002380013}],
#       'length': 11.0},
#      {'points': [{'lat': 1.4038299769163132, 'lng': 103.70145002380013},
#        {'lat': 1.404229961335659, 'lng': 103.70166996493936}],
#       'length': 51.0},
#      {'points': [{'lat': 1.404229961335659, 'lng': 103.70166996493936},
#        {'lat': 1.404500026255846, 'lng': 103.70181002654135}],
#       'length': 34.0},
#      {'points': [{'lat': 1.404500026255846, 'lng': 103.70181002654135},
#        {'lat': 1.4046099968254566, 'lng': 103.70187004096806},
#        {'lat': 1.4047199673950672, 'lng': 103.70191999711096}],
#       'length': 27.0},
#      {'points': [{'lat': 1.4047199673950672, 'lng': 103.70191999711096},
#        {'lat': 1.4049199596047401, 'lng': 103.70199996046722},
#        {'lat': 1.4050699956715107, 'lng': 103.70204002596438},
#        {'lat': 1.4052600134164095, 'lng': 103.70208000764251},
#        {'lat': 1.4054800383746624, 'lng': 103.70211001485586},
#        {'lat': 1.4056900050491095, 'lng': 103.70211998932064},
#        {'lat': 1.4058699645102024, 'lng': 103.70211998932064},
#        {'lat': 1.4060599822551012, 'lng': 103.70210004039109}],
#       'length': 152.0},
#      {'points': [{'lat': 1.4060599822551012, 'lng': 103.70210004039109},
#        {'lat': 1.4062599744647741, 'lng': 103.70205000042915},
#        {'lat': 1.406429959461093, 'lng': 103.70199996046722},
#        {'lat': 1.4066300354897976, 'lng': 103.70194002985954}],
#       'length': 66.0},
#      {'points': [{'lat': 1.4066300354897976, 'lng': 103.70194002985954},
#        {'lat': 1.4068600349128246, 'lng': 103.70185998268425}],
#       'length': 27.0},
#      {'points': [{'lat': 1.4068600349128246, 'lng': 103.70185998268425},
#        {'lat': 1.4072900265455246, 'lng': 103.70172000490129},
#        {'lat': 1.4083500020205975, 'lng': 103.70138003490865},
#        {'lat': 1.4088799897581339, 'lng': 103.7012099660933},
#        {'lat': 1.4092600252479315, 'lng': 103.70106998831034},
#        {'lat': 1.409569988027215, 'lng': 103.70094995945692},
#        {'lat': 1.4098600018769503, 'lng': 103.70083001442254},
#        {'lat': 1.4104100223630667, 'lng': 103.70060001499951},
#        {'lat': 1.4110300317406654, 'lng': 103.70033003389835}],
#       'length': 494.0},
#      {'points': [{'lat': 1.4110300317406654, 'lng': 103.70033003389835},
#        {'lat': 1.4116399828344584, 'lng': 103.70004999451339}],
#       'length': 75.0},
#      {'points': [{'lat': 1.4116399828344584, 'lng': 103.70004999451339},
#        {'lat': 1.4118500333279371, 'lng': 103.69994999840856},
#        {'lat': 1.41200996004045, 'lng': 103.69988000951707},
#        {'lat': 1.4121800288558006, 'lng': 103.69981002062559}],
#       'length': 66.0},
#      {'points': [{'lat': 1.4121800288558006, 'lng': 103.69981002062559},
#        {'lat': 1.412280024960637, 'lng': 103.6997299734503},
#        {'lat': 1.4123699627816677, 'lng': 103.6996800173074},
#        {'lat': 1.41248001717031, 'lng': 103.69962000288069},
#        {'lat': 1.4125500060617924, 'lng': 103.69958999566734},
#        {'lat': 1.412659976631403, 'lng': 103.69955001398921},
#        {'lat': 1.4127599727362394, 'lng': 103.69952000677586},
#        {'lat': 1.4129000343382359, 'lng': 103.69949997402728},
#        {'lat': 1.4130499865859747, 'lng': 103.6994899995625}],
#       'length': 105.0},
#      {'points': [{'lat': 1.4130499865859747, 'lng': 103.6994899995625},
#        {'lat': 1.4131799899041653, 'lng': 103.69949997402728},
#        {'lat': 1.4132899604737759, 'lng': 103.69952000677586},
#        {'lat': 1.413370007649064, 'lng': 103.69954003952444},
#        {'lat': 1.4134799782186747, 'lng': 103.69956996291876}],
#       'length': 49.0},
#      {'points': [{'lat': 1.4134799782186747, 'lng': 103.69956996291876},
#        {'lat': 1.4136499632149935, 'lng': 103.69962000288069},
#        {'lat': 1.4137600176036358, 'lng': 103.69965001009405},
#        {'lat': 1.4139600098133087, 'lng': 103.69969996623695},
#        {'lat': 1.4140800386667252, 'lng': 103.69977003894746}],
#       'length': 71.0},
#      {'points': [{'lat': 1.4140800386667252, 'lng': 103.69977003894746},
#        {'lat': 1.414209958165884, 'lng': 103.69981002062559},
#        {'lat': 1.4143599942326546, 'lng': 103.6998700350523},
#        {'lat': 1.4144999720156193, 'lng': 103.69992996565998}],
#       'length': 50.0},
#      {'points': [{'lat': 1.4144999720156193, 'lng': 103.69992996565998},
#        {'lat': 1.4153000246733427, 'lng': 103.700300026685},
#        {'lat': 1.416009971871972, 'lng': 103.70063002221286},
#        {'lat': 1.4175600372254848, 'lng': 103.70133996941149}],
#       'length': 374.0},
#      {'points': [{'lat': 1.4175600372254848, 'lng': 103.70133996941149},
#        {'lat': 1.418020036071539, 'lng': 103.70155001990497}],
#       'length': 56.0},
#      {'points': [{'lat': 1.418020036071539, 'lng': 103.70155001990497},
#        {'lat': 1.421319991350174, 'lng': 103.70310000143945}],
#       'length': 405.0}]}},
#   'currentFlow': {'speed': 14.722222,
#    'speedUncapped': 14.722222,
#    'freeFlow': 15.833334,
#    'jamFactor': 0.5,
#    'confidence': 0.78,
#    'traversability': 'open'}},
#  {'location': {'description': 'TPE/Tampines Expy',
#    'length': 455.0,
#    'shape': {'links': [{'points': [{'lat': 1.3944000005722046,
#         'lng': 103.90150995925069},
#        {'lat': 1.3945300038903952, 'lng': 103.90161003917456},
#        {'lat': 1.3946800399571657, 'lng': 103.90173995867372},
#        {'lat': 1.3948299922049046, 'lng': 103.90188999474049},
#        {'lat': 1.394950021058321, 'lng': 103.9020100235939},
#        {'lat': 1.3950800243765116, 'lng': 103.9021400269121}],
#       'length': 103.0},
#      {'points': [{'lat': 1.3950800243765116, 'lng': 103.9021400269121},
#        {'lat': 1.395180020481348, 'lng': 103.90224002301693}],
#       'length': 16.0},
#      {'points': [{'lat': 1.395180020481348, 'lng': 103.90224002301693},
#        {'lat': 1.3954299688339233, 'lng': 103.9024899713695}],
#       'length': 39.0},
#      {'points': [{'lat': 1.3954299688339233, 'lng': 103.9024899713695},
#        {'lat': 1.3956000376492739, 'lng': 103.90266004018486},
#        {'lat': 1.3957100082188845, 'lng': 103.90276003628969}],
#       'length': 43.0},
#      {'points': [{'lat': 1.3957100082188845, 'lng': 103.90276003628969},
#        {'lat': 1.3958499860018492, 'lng': 103.9028700068593},
#        {'lat': 1.3959600403904915, 'lng': 103.90294997021556}],
#       'length': 35.0},
#      {'points': [{'lat': 1.3959600403904915, 'lng': 103.90294997021556},
#        {'lat': 1.3961600326001644, 'lng': 103.90309003181756}],
#       'length': 27.0},
#      {'points': [{'lat': 1.3961600326001644, 'lng': 103.90309003181756},
#        {'lat': 1.3963900320231915, 'lng': 103.9032399840653},
#        {'lat': 1.3965499587357044, 'lng': 103.90333000570536}],
#       'length': 51.0},
#      {'points': [{'lat': 1.3965499587357044, 'lng': 103.90333000570536},
#        {'lat': 1.396709969267249, 'lng': 103.90340996906161},
#        {'lat': 1.3968600053340197, 'lng': 103.90348004177213},
#        {'lat': 1.3969999831169844, 'lng': 103.90355003066361}],
#       'length': 56.0},
#      {'points': [{'lat': 1.3969999831169844, 'lng': 103.90355003066361},
#        {'lat': 1.3972800225019455, 'lng': 103.90371004119515}],
#       'length': 36.0},
#      {'points': [{'lat': 1.3972800225019455, 'lng': 103.90371004119515},
#        {'lat': 1.3973100297152996, 'lng': 103.90372001565993}],
#       'length': 4.0},
#      {'points': [{'lat': 1.3973100297152996, 'lng': 103.90372001565993},
#        {'lat': 1.3976700324565172, 'lng': 103.90389997512102}],
#       'length': 45.0}]}},
#   'currentFlow': {'speed': 6.666667,
#    'speedUncapped': 6.666667,
#    'freeFlow': 10.0,
#    'jamFactor': 2.2,
#    'confidence': 0.99,
#    'traversability': 'open'}},
#  {'location': {'description': 'Pasir Ris Dr 8/Tampines Ave 12/Exit 3A/Exit 3C',
#    'length': 905.0,
#    'shape': {'links': [{'points': [{'lat': 1.3708200305700302,
#         'lng': 103.94137001596391},
#        {'lat': 1.3706300128251314, 'lng': 103.94159004092216},
#        {'lat': 1.3703700061887503, 'lng': 103.94187997095287}],
#       'length': 76.0},
#      {'points': [{'lat': 1.3703700061887503, 'lng': 103.94187997095287},
#        {'lat': 1.3702600356191397, 'lng': 103.94199999980628},
#        {'lat': 1.3698899745941162, 'lng': 103.94239998422563}],
#       'length': 79.0},
#      {'points': [{'lat': 1.3698899745941162, 'lng': 103.94239998422563},
#        {'lat': 1.3695199973881245, 'lng': 103.94279996864498},
#        {'lat': 1.3692500162869692, 'lng': 103.94308000802994},
#        {'lat': 1.3691100385040045, 'lng': 103.94322996027768},
#        {'lat': 1.3690099585801363, 'lng': 103.9433499891311},
#        {'lat': 1.368980035185814, 'lng': 103.94338997080922}],
#       'length': 149.0},
#      {'points': [{'lat': 1.368980035185814, 'lng': 103.94338997080922},
#        {'lat': 1.3687500357627869, 'lng': 103.94366003572941},
#        {'lat': 1.3685999996960163, 'lng': 103.94386002793908}],
#       'length': 67.0},
#      {'points': [{'lat': 1.3685999996960163, 'lng': 103.94386002793908},
#        {'lat': 1.3684099819511175, 'lng': 103.94412003457546},
#        {'lat': 1.3681499753147364, 'lng': 103.94452999345958},
# ...
#        {'lat': 1.3381700031459332, 'lng': 103.6361900344491}],
#       'length': 33.0},
#      {'points': [{'lat': 1.3381700031459332, 'lng': 103.6361900344491},
#        {'lat': 1.3363300077617168, 'lng': 103.63554999232292}],
#       'length': 216.0},
#      {'points': [{'lat': 1.3363300077617168, 'lng': 103.63554999232292},
#        {'lat': 1.3362699933350086, 'lng': 103.63548000343144},
#        {'lat': 1.336160022765398, 'lng': 103.63544002175331}],
#       'length': 23.0},
#      {'points': [{'lat': 1.336160022765398, 'lng': 103.63544002175331},
#        {'lat': 1.3356300350278616, 'lng': 103.63525997847319},
#        {'lat': 1.3352800067514181, 'lng': 103.6351400334388}],
#       'length': 103.0},
#      {'points': [{'lat': 1.3352800067514181, 'lng': 103.6351400334388},
#        {'lat': 1.3351599778980017, 'lng': 103.63509996794164}],
#       'length': 14.0},
#      {'points': [{'lat': 1.3351599778980017, 'lng': 103.63509996794164},
#        {'lat': 1.3349599856883287, 'lng': 103.63498999737203}],
#       'length': 25.0},
#      {'points': [{'lat': 1.3349599856883287, 'lng': 103.63498999737203},
#        {'lat': 1.3347200118005276, 'lng': 103.63489997573197}],
#       'length': 28.0},
#      {'points': [{'lat': 1.3347200118005276, 'lng': 103.63489997573197},
#        {'lat': 1.334569975733757, 'lng': 103.63483996130526}],
#       'length': 18.0},
#      {'points': [{'lat': 1.334569975733757, 'lng': 103.63483996130526},
#        {'lat': 1.3344500306993723, 'lng': 103.63479000516236}],
#       'length': 14.0}]}},
#   'currentFlow': {'speed': 11.111112,
#    'speedUncapped': 11.111112,
#    'freeFlow': 11.388889,
#    'jamFactor': 0.1,
#    'confidence': 0.73,
#    'traversability': 'open'}},
#  {'location': {'description': 'Upp Paya Lebar Rd (South)',
#    'length': 275.0,
#    'shape': {'links': [{'points': [{'lat': 1.340390034019947,
#         'lng': 103.88569003902376},
#        {'lat': 1.3402099907398224, 'lng': 103.8858399912715}],
#       'length': 26.0},
#      {'points': [{'lat': 1.3402099907398224, 'lng': 103.8858399912715},
#        {'lat': 1.3399799913167953, 'lng': 103.8860300090164}],
#       'length': 33.0},
#      {'points': [{'lat': 1.3399799913167953, 'lng': 103.8860300090164},
#        {'lat': 1.3397799991071224, 'lng': 103.88619001954794},
#        {'lat': 1.3395800068974495, 'lng': 103.88633997179568},
#        {'lat': 1.3393800146877766, 'lng': 103.88648003339767},
#        {'lat': 1.3391100335866213, 'lng': 103.88663996011019}],
#       'length': 118.0},
#      {'points': [{'lat': 1.3391100335866213, 'lng': 103.88663996011019},
#        {'lat': 1.3388800341635942, 'lng': 103.88675001449883}],
#       'length': 28.0},
#      {'points': [{'lat': 1.3388800341635942, 'lng': 103.88675001449883},
#        {'lat': 1.3386399764567614, 'lng': 103.88686995953321},
#        {'lat': 1.3384600169956684, 'lng': 103.8869500067085}],
#       'length': 52.0},
#      {'points': [{'lat': 1.3384600169956684, 'lng': 103.8869500067085},
#        {'lat': 1.3383099809288979, 'lng': 103.88701999559999}],
#       'length': 18.0}]}},
#   'currentFlow': {'speed': 12.5,
#    'speedUncapped': 12.5,
#    'freeFlow': 14.444445,
#    'jamFactor': 1.2,
#    'confidence': 0.96,
#    'traversability': 'open'}},
#  {'location': {'description': 'Dunman Rd',
#    'length': 267.0,
#    'shape': {'links': [{'points': [{'lat': 1.3080300204455853,
#         'lng': 103.88669000007212},
#        {'lat': 1.3081300165504217, 'lng': 103.88717003166676}],
#       'length': 54.0},
#      {'points': [{'lat': 1.3081300165504217, 'lng': 103.88717003166676},
#        {'lat': 1.3082399871200323, 'lng': 103.88774000108242},
#        {'lat': 1.3082600198686123, 'lng': 103.88783999718726}],
#       'length': 76.0},
#      {'points': [{'lat': 1.3082600198686123, 'lng': 103.88783999718726},
#        {'lat': 1.3083099760115147, 'lng': 103.88807997107506}],
#       'length': 27.0},
#      {'points': [{'lat': 1.3083099760115147, 'lng': 103.88807997107506},
#        {'lat': 1.3084099721163511, 'lng': 103.88858003541827}],
#       'length': 57.0},
#      {'points': [{'lat': 1.3084099721163511, 'lng': 103.88858003541827},
#        {'lat': 1.3085099682211876, 'lng': 103.8890500087291}],
#       'length': 53.0}]}},
#   'currentFlow': {'speed': 12.222222,
#    'speedUncapped': 12.222222,
#    'freeFlow': 11.111112,
#    'jamFactor': 0.0,
#    'confidence': 0.91,
#    'traversability': 'open'}},
#  {'location': {'description': 'CTE/Kampong Java Flyover/Central Expy',
#    'length': 25.0,
#    'shape': {'links': [{'points': [{'lat': 1.3139899726957083,
#         'lng': 103.84546000510454},
#        {'lat': 1.313770031556487, 'lng': 103.84542999789119}],
#       'length': 25.0}]}},
#   'currentFlow': {'speed': 6.111111,
#    'speedUncapped': 6.111111,
#    'freeFlow': 7.5,
#    'jamFactor': 1.5,
#    'confidence': 0.7,
#    'traversability': 'open'}},
#  {'location': {'description': 'Choa Chu Kang Ave 3',
#    'length': 155.0,
#    'shape': {'links': [{'points': [{'lat': 1.3849599659442902,
#         'lng': 103.74639999121428},
#        {'lat': 1.3848800025880337, 'lng': 103.7464399728924}],
#       'length': 10.0},
#      {'points': [{'lat': 1.3848800025880337, 'lng': 103.7464399728924},
#        {'lat': 1.3847299665212631, 'lng': 103.74652999453247},
#        {'lat': 1.3843899965286255, 'lng': 103.74675001949072}],
#       'length': 64.0},
#      {'points': [{'lat': 1.3843899965286255, 'lng': 103.74675001949072},
#        {'lat': 1.3841800298541784, 'lng': 103.74688002280891}],
#       'length': 27.0},
#      {'points': [{'lat': 1.3841800298541784, 'lng': 103.74688002280891},
#        {'lat': 1.384009961038828, 'lng': 103.74698999337852}],
#       'length': 22.0},
#      {'points': [{'lat': 1.384009961038828, 'lng': 103.74698999337852},
#        {'lat': 1.3839600048959255, 'lng': 103.74702000059187}],
#       'length': 6.0},
#      {'points': [{'lat': 1.3839600048959255, 'lng': 103.74702000059187},
#        {'lat': 1.3837699871510267, 'lng': 103.74715997837484}],
#       'length': 26.0}]}},
#   'currentFlow': {'speed': 7.5,
#    'speedUncapped': 7.5,
#    'freeFlow': 10.277778,
#    'jamFactor': 1.7,
#    'confidence': 0.99,
#    'traversability': 'open'}},
#  {'location': {'description': 'Woodlands Rd/Upp Bukit Timah Rd',
#    'length': 22.0,
#    'shape': {'links': [{'points': [{'lat': 1.379839964210987,
#         'lng': 103.76140996813774},
#        {'lat': 1.3799100369215012, 'lng': 103.76159998588264}],
#       'length': 22.0}]}},
#   'currentFlow': {'speed': 5.277778,
#    'speedUncapped': 5.277778,
#    'freeFlow': 11.111112,
#    'jamFactor': 3.8,
#    'confidence': 0.99,
#    'traversability': 'open'}},
#  {'location': {'description': 'Holland Grove Rd',
#    'length': 447.0,
#    'shape': {'links': [{'points': [{'lat': 1.3128900155425072,
#         'lng': 103.78578999079764},
#        {'lat': 1.3131699711084366, 'lng': 103.78565001301467}],
#       'length': 35.0},
#      {'points': [{'lat': 1.3131699711084366, 'lng': 103.78565001301467},
#        {'lat': 1.313310032710433, 'lng': 103.78558002412319}],
#       'length': 17.0},
#      {'points': [{'lat': 1.313310032710433, 'lng': 103.78558002412319},
#        {'lat': 1.3134800177067518, 'lng': 103.78549000248313}],
#       'length': 21.0},
#      {'points': [{'lat': 1.3134800177067518, 'lng': 103.78549000248313},
#        {'lat': 1.313719991594553, 'lng': 103.78535999916494}],
#       'length': 30.0},
#      {'points': [{'lat': 1.313719991594553, 'lng': 103.78535999916494},
#        {'lat': 1.313919983804226, 'lng': 103.7852600030601}],
#       'length': 25.0},
#      {'points': [{'lat': 1.313919983804226, 'lng': 103.7852600030601},
#        {'lat': 1.314430022612214, 'lng': 103.78499002195895}],
#       'length': 64.0},
#      {'points': [{'lat': 1.314430022612214, 'lng': 103.78499002195895},
#        {'lat': 1.3145399931818247, 'lng': 103.78493000753224}],
#       'length': 14.0},
#      {'points': [{'lat': 1.3145399931818247, 'lng': 103.78493000753224},
#        {'lat': 1.3147000037133694, 'lng': 103.78484996035695}],
#       'length': 20.0},
#      {'points': [{'lat': 1.3147000037133694, 'lng': 103.78484996035695},
#        {'lat': 1.3147699926048517, 'lng': 103.78480997867882},
#        {'lat': 1.3148200325667858, 'lng': 103.78477997146547},
#        {'lat': 1.3148699887096882, 'lng': 103.78473998978734}],
#       'length': 23.0},
#      {'points': [{'lat': 1.3148699887096882, 'lng': 103.78473998978734},
#        {'lat': 1.3149200286716223, 'lng': 103.78469003364444},
#        {'lat': 1.3149600103497505, 'lng': 103.78463001921773},
#        {'lat': 1.3149900175631046, 'lng': 103.7845799792558}],
#       'length': 22.0},
#      {'points': [{'lat': 1.3149900175631046, 'lng': 103.7845799792558},
#        {'lat': 1.315039973706007, 'lng': 103.78447998315096}],
#       'length': 12.0},
#      {'points': [{'lat': 1.315039973706007, 'lng': 103.78447998315096},
#        {'lat': 1.3150699809193611, 'lng': 103.78441996872425},
#        {'lat': 1.3151399698108435, 'lng': 103.7842100020498}],
#       'length': 32.0},
#      {'points': [{'lat': 1.3151399698108435, 'lng': 103.7842100020498},
#        {'lat': 1.3153900019824505, 'lng': 103.7835299782455}],
#       'length': 80.0},
#      {'points': [{'lat': 1.3153900019824505, 'lng': 103.7835299782455},
#        {'lat': 1.315469965338707, 'lng': 103.78331003710628}],
#       'length': 26.0},
#      {'points': [{'lat': 1.315469965338707, 'lng': 103.78331003710628},
#        {'lat': 1.3155500125139952, 'lng': 103.78309001214802}],
#       'length': 26.0}]}},
#   'currentFlow': {'speed': 7.2222223,
#    'speedUncapped': 7.2222223,
#    'freeFlow': 9.722222,
#    'jamFactor': 1.3,
#    'confidence': 0.81,
#    'traversability': 'open'}},
#  {'location': {'description': 'PIE/PAN ISLAND EXPY EASTBOUND',
#    'length': 199.0,
#    'shape': {'links': [{'points': [{'lat': 1.3485100027173758,
#         'lng': 103.7347199767828},
#        {'lat': 1.3474900089204311, 'lng': 103.73592001385987}],
#       'length': 175.0},
#      {'points': [{'lat': 1.3474900089204311, 'lng': 103.73592001385987},
#        {'lat': 1.3473500311374664, 'lng': 103.73608002439141}],
#       'length': 24.0}]}},
#   'currentFlow': {'speed': 13.888889,
#    'speedUncapped': 16.666668,
#    'freeFlow': 13.888889,
#    'jamFactor': 0.0,
#    'confidence': 0.73,
#    'traversability': 'open'}},
#  {'location': {'description': 'Anchorvale Dr',
#    'length': 267.0,
#    'shape': {'links': [{'points': [{'lat': 1.3898799754679203,
#         'lng': 103.88547998853028},
#        {'lat': 1.3901500403881073, 'lng': 103.8856499735266}],
#       'length': 35.0},
#      {'points': [{'lat': 1.3901500403881073, 'lng': 103.8856499735266},
#        {'lat': 1.3903299998492002, 'lng': 103.88576002791524}],
#       'length': 23.0},
#      {'points': [{'lat': 1.3903299998492002, 'lng': 103.88576002791524},
#        {'lat': 1.3904600031673908, 'lng': 103.8858399912715}],
#       'length': 17.0},
#      {'points': [{'lat': 1.3904600031673908, 'lng': 103.8858399912715},
#        {'lat': 1.3906900025904179, 'lng': 103.88596999458969}],
#       'length': 29.0},
#      {'points': [{'lat': 1.3906900025904179, 'lng': 103.88596999458969},
#        {'lat': 1.3908699620515108, 'lng': 103.88606999069452}],
#       'length': 23.0},
#      {'points': [{'lat': 1.3908699620515108, 'lng': 103.88606999069452},
#        {'lat': 1.3910500053316355, 'lng': 103.88616998679936}],
#       'length': 23.0},
#      {'points': [{'lat': 1.3910500053316355, 'lng': 103.88616998679936},
#        {'lat': 1.3910999614745378, 'lng': 103.88619999401271},
#        {'lat': 1.3913000375032425, 'lng': 103.88630996458232}],
#       'length': 32.0},
#      {'points': [{'lat': 1.3913000375032425, 'lng': 103.88630996458232},
#        {'lat': 1.3915700186043978, 'lng': 103.88646997511387}],
#       'length': 35.0},
#      {'points': [{'lat': 1.3915700186043978, 'lng': 103.88646997511387},
#        {'lat': 1.3917000219225883, 'lng': 103.88655002228916}],
#       'length': 17.0},
#      {'points': [{'lat': 1.3917000219225883, 'lng': 103.88655002228916},
#        {'lat': 1.3917600363492966, 'lng': 103.88658002950251}],
#       'length': 7.0},
#      {'points': [{'lat': 1.3917600363492966, 'lng': 103.88658002950251},
#        {'lat': 1.3919600285589695, 'lng': 103.8866999745369}],
#       'length': 26.0}]}},
#   'currentFlow': {'speed': 7.2222223,
#    'speedUncapped': 7.2222223,
#    'freeFlow': 8.611112,
#    'jamFactor': 0.6,
#    'confidence': 0.72,
#    'traversability': 'open'}},
#  {'location': {'description': 'UPP THOMSON RD SOUTHBOUND',
#    'length': 80.0,
#    'shape': {'links': [{'points': [{'lat': 1.393559966236353,
#         'lng': 103.81867999210954},
#        {'lat': 1.3936899695545435, 'lng': 103.81864001043141},
#        {'lat': 1.3937799911946058, 'lng': 103.81861000321805},
#        {'lat': 1.3938499800860882, 'lng': 103.8185799960047}],
#       'length': 34.0},
#      {'points': [{'lat': 1.3938499800860882, 'lng': 103.8185799960047},
#        {'lat': 1.3939300272613764, 'lng': 103.81854001432657},
#        {'lat': 1.3939900416880846, 'lng': 103.81850003264844},
#        {'lat': 1.394049972295761, 'lng': 103.81844999268651},
#        {'lat': 1.394090037792921, 'lng': 103.81840003654361},
#        {'lat': 1.3941499684005976, 'lng': 103.81831001490355}],
#       'length': 46.0}]}},
#   'currentFlow': {'speed': 13.888889,
#    'speedUncapped': 14.166667,
#    'freeFlow': 11.111112,
#    'jamFactor': 0.0,
#    'confidence': 0.92,
#    'traversability': 'open'}},
#  {'location': {'description': 'Ang Mo Kio Ave 9',
#    'length': 602.0,
#    'shape': {'links': [{'points': [{'lat': 1.377149960026145,
#         'lng': 103.83955000899732},
#        {'lat': 1.3777500204741955, 'lng': 103.83964003063738}],
#       'length': 67.0},
#      {'points': [{'lat': 1.3777500204741955, 'lng': 103.83964003063738},
#        {'lat': 1.3782199937850237, 'lng': 103.83971001952887}],
#       'length': 53.0},
#      {'points': [{'lat': 1.3782199937850237, 'lng': 103.83971001952887},
#        {'lat': 1.378280008211732, 'lng': 103.83971999399364}],
#       'length': 7.0},
#      {'points': [{'lat': 1.378280008211732, 'lng': 103.83971999399364},
#        {'lat': 1.3785499893128872, 'lng': 103.83975997567177}],
#       'length': 30.0},
#      {'points': [{'lat': 1.3785499893128872, 'lng': 103.83975997567177},
#        {'lat': 1.3788099959492683, 'lng': 103.83978998288512},
#        {'lat': 1.3790199626237154, 'lng': 103.83980004116893},
#        {'lat': 1.37922003865242, 'lng': 103.83980004116893},
#        {'lat': 1.3794099725782871, 'lng': 103.83978998288512},
#        {'lat': 1.3795500341802835, 'lng': 103.83978000842035}],
#       'length': 111.0},
#      {'points': [{'lat': 1.3795500341802835, 'lng': 103.83978000842035},
#        {'lat': 1.3797299936413765, 'lng': 103.83975997567177},
#        {'lat': 1.3798999786376953, 'lng': 103.83972996845841},
#        {'lat': 1.3800500147044659, 'lng': 103.83969996124506}],
#       'length': 56.0},
#      {'points': [{'lat': 1.3800500147044659, 'lng': 103.83969996124506},
#        {'lat': 1.3801699597388506, 'lng': 103.83967003785074},
#        {'lat': 1.3803199958056211, 'lng': 103.83962997235358}],
#       'length': 31.0},
#      {'points': [{'lat': 1.3803199958056211, 'lng': 103.83962997235358},
#        {'lat': 1.3805299624800682, 'lng': 103.8395599834621},
#        {'lat': 1.3807300385087729, 'lng': 103.83948999457061}],
#       'length': 48.0},
#      {'points': [{'lat': 1.3807300385087729, 'lng': 103.83948999457061},
#        {'lat': 1.3808700162917376, 'lng': 103.8394299801439},
#        {'lat': 1.3809899613261223, 'lng': 103.8393699657172},
#        {'lat': 1.3811199646443129, 'lng': 103.83929997682571}],
#       'length': 48.0},
#      {'points': [{'lat': 1.3811199646443129, 'lng': 103.83929997682571},
#        {'lat': 1.3812799751758575, 'lng': 103.83921003900468}],
#       'length': 20.0},
#      {'points': [{'lat': 1.3812799751758575, 'lng': 103.83921003900468},
#        {'lat': 1.382080027833581, 'lng': 103.83872003294528}],
#       'length': 104.0},
#      {'points': [{'lat': 1.382080027833581, 'lng': 103.83872003294528},
#        {'lat': 1.3822100311517715, 'lng': 103.83863998576999}],
#       'length': 17.0},
#      {'points': [{'lat': 1.3822100311517715, 'lng': 103.83863998576999},
#        {'lat': 1.382280020043254, 'lng': 103.83859002962708}],
#       'length': 10.0}]}},
#   'currentFlow': {'speed': 7.5,
#    'speedUncapped': 7.5,
#    'freeFlow': 11.111112,
#    'jamFactor': 2.2,
#    'confidence': 0.91,
#    'traversability': 'open'}},
#  ...]

# %%
raw_df = pd.DataFrame(data)

# %%
raw_df = pd.concat([raw_df['location'].apply(pd.Series), raw_df['currentFlow'].apply(pd.Series)], axis=1)

# %% [markdown]
# **Extract the beginning and end points of the road**

# %%
raw_df['start_lat'] = raw_df['shape'][0]['links'][0]['points'][0]['lat']
raw_df['start_lon'] = raw_df['shape'][0]['links'][0]['points'][0]['lng']
raw_df['end_lat'] = raw_df['shape'][0]['links'][0]['points'][-1]['lat']
raw_df['end_lon'] = raw_df['shape'][0]['links'][0]['points'][-1]['lng']

# %%
raw_df.head()
# Out:
#                    description  length  \
# 0           Changi South Ave 2    92.0
# 1          ECP/East Coast Pkwy    44.0
# 2                     Benoi Rd   511.0
# 3            Jalan Kebun Limau   457.0
# 4  Jurong Town Hall Rd/Exit 13  1734.0
#
#                                                shape      speed  \
# 0  {'links': [{'points': [{'lat': 1.3317399937659...  11.666667
# 1  {'links': [{'points': [{'lat': 1.3121199700981...  17.777779
# 2  {'links': [{'points': [{'lat': 1.3087099604308...   8.888889
# 3  {'links': [{'points': [{'lat': 1.3168200384825...   9.166667
# 4  {'links': [{'points': [{'lat': 1.3186700083315...  21.388890
#
#    speedUncapped   freeFlow  jamFactor  confidence traversability subSegments  \
# 0      11.666667  10.277778        0.0        0.92           open         NaN
# 1      17.777779  13.888889        0.0        0.70           open         NaN
# 2       8.888889  12.500000        1.9        0.76           open         NaN
# 3       9.166667  13.055556        1.8        0.99           open         NaN
# 4      21.388890  20.833334        0.0        0.99           open         NaN
#
#   junctionTraversability  start_lat  start_lon  end_lat    end_lon
# 0                    NaN    1.33174  103.96608  1.33246  103.96649
# 1                    NaN    1.33174  103.96608  1.33246  103.96649
# 2                    NaN    1.33174  103.96608  1.33246  103.96649
# 3                    NaN    1.33174  103.96608  1.33246  103.96649
# 4                    NaN    1.33174  103.96608  1.33246  103.96649

# %% [markdown]
# # Pre-Processing Data

# %% [markdown]
# ### Handle missing values

# %% [markdown]
# **Drop the shape feature**

# %%
raw_df = raw_df.drop("shape", axis=1)

# %% [markdown]
# **Drop subSegments, junctionTraversability, jamTendency, as only a small number of records have these features**

# %%
columns_to_drop = ['subSegments', 'junctionTraversability', 'jamTendency']

# %%
columns_to_drop = [col for col in columns_to_drop if col in raw_df.columns]

# %%
raw_df = raw_df.drop(columns_to_drop, axis=1)

# %% [markdown]
# **Roads that are closed have no traffic features**

# %%
null_rows = raw_df['speed'].isnull()
null_data = raw_df[null_rows]

# %%
null_data.head()
# Out:
#                          description  length  speed  speedUncapped   freeFlow  \
# 162   Paisr Ris Dr 3/New Loyang Link   386.0    NaN            NaN  11.111112
# 514   Pasir Ris Dr 4/Pasir Ris St 12   405.0    NaN            NaN  11.944445
# 1450           Jalan Lingkaran Dalam   174.0    NaN            NaN   9.166667
# 1732                      Loyang Way   632.0    NaN            NaN  14.166667
# 2620                    Marymount Rd   354.0    NaN            NaN   9.722222
#
#       jamFactor  confidence traversability  start_lat  start_lon  end_lat  \
# 162        10.0         NaN         closed    1.33174  103.96608  1.33246
# 514        10.0         NaN         closed    1.33174  103.96608  1.33246
# 1450       10.0         NaN         closed    1.33174  103.96608  1.33246
# 1732       10.0         NaN         closed    1.33174  103.96608  1.33246
# 2620       10.0         NaN         closed    1.33174  103.96608  1.33246
#
#         end_lon
# 162   103.96649
# 514   103.96649
# 1450  103.96649
# 1732  103.96649
# 2620  103.96649

# %% [markdown]
# **Select rows where traversibility is open**

# %%
open_df = raw_df.loc[raw_df['traversability'] == "open"].copy()

# %%
open_df = open_df.drop("traversability", axis=1)

# %%
open_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5506 entries, 0 to 5515
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   description    5502 non-null   object
#  1   length         5506 non-null   float64
#  2   speed          5506 non-null   float64
#  3   speedUncapped  5506 non-null   float64
#  4   freeFlow       5506 non-null   float64
#  5   jamFactor      5506 non-null   float64
#  6   confidence     5506 non-null   float64
#  7   start_lat      5506 non-null   float64
#  8   start_lon      5506 non-null   float64
#  9   end_lat        5506 non-null   float64
#  10  end_lon        5506 non-null   float64
# dtypes: float64(10), object(1)
# memory usage: 516.2+ KB

# %% [markdown]
# **There are still some records without a road name description**

# %%
open_df.dropna(inplace=True)

# %%
open_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5502 entries, 0 to 5515
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   description    5502 non-null   object
#  1   length         5502 non-null   float64
#  2   speed          5502 non-null   float64
#  3   speedUncapped  5502 non-null   float64
#  4   freeFlow       5502 non-null   float64
#  5   jamFactor      5502 non-null   float64
#  6   confidence     5502 non-null   float64
#  7   start_lat      5502 non-null   float64
#  8   start_lon      5502 non-null   float64
#  9   end_lat        5502 non-null   float64
#  10  end_lon        5502 non-null   float64
# dtypes: float64(10), object(1)
# memory usage: 515.8+ KB

# %%
road_list = open_df["description"].unique().tolist()

# %%
road_list = sorted([str(item) for item in road_list])

# %%
len(road_list)
# Out:
# 1538

# %%
for item in road_list:
    if type(item) == float:
        print("hey")

# %%
df = open_df.copy()

# %% [markdown]
# **Drop road metadata**

# %%
#df = df.drop("olr", axis=1)

# %% [markdown]
# **Confidence <br>
# <br>
# 0.7 < confidence <= 1.0 indicates real time speeds <br>
# 0.5 < confidence <= 0.7 indicates historical speeds <br>
# 0.0 < confidence <= 0.5 indicates speed limit**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5502 entries, 0 to 5515
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   description    5502 non-null   object
#  1   length         5502 non-null   float64
#  2   speed          5502 non-null   float64
#  3   speedUncapped  5502 non-null   float64
#  4   freeFlow       5502 non-null   float64
#  5   jamFactor      5502 non-null   float64
#  6   confidence     5502 non-null   float64
#  7   start_lat      5502 non-null   float64
#  8   start_lon      5502 non-null   float64
#  9   end_lat        5502 non-null   float64
#  10  end_lon        5502 non-null   float64
# dtypes: float64(10), object(1)
# memory usage: 515.8+ KB

# %%
df.head()
# Out:
#                    description  length      speed  speedUncapped   freeFlow  \
# 0           Changi South Ave 2    92.0  11.666667      11.666667  10.277778
# 1          ECP/East Coast Pkwy    44.0  17.777779      17.777779  13.888889
# 2                     Benoi Rd   511.0   8.888889       8.888889  12.500000
# 3            Jalan Kebun Limau   457.0   9.166667       9.166667  13.055556
# 4  Jurong Town Hall Rd/Exit 13  1734.0  21.388890      21.388890  20.833334
#
#    jamFactor  confidence  start_lat  start_lon  end_lat    end_lon
# 0        0.0        0.92    1.33174  103.96608  1.33246  103.96649
# 1        0.0        0.70    1.33174  103.96608  1.33246  103.96649
# 2        1.9        0.76    1.33174  103.96608  1.33246  103.96649
# 3        1.8        0.99    1.33174  103.96608  1.33246  103.96649
# 4        0.0        0.99    1.33174  103.96608  1.33246  103.96649

# %%
#df["confidence"] = pd.cut(df["confidence"], bins=[0.0, 0.5, 0.7, 1.0], labels=["Speed Limit", "Historical Speeds", "Real-Time Speeds"])

# %%
#df = pd.get_dummies(df, columns=["confidence"])

# %%
#df.head()

# %%
#df.to_csv('./test.csv', index=False)

# %%
#label_encoder = LabelEncoder()
#df['traversability'] = label_encoder.fit_transform(df['traversability'])

# %%
df.head()
# Out:
#                    description  length      speed  speedUncapped   freeFlow  \
# 0           Changi South Ave 2    92.0  11.666667      11.666667  10.277778
# 1          ECP/East Coast Pkwy    44.0  17.777779      17.777779  13.888889
# 2                     Benoi Rd   511.0   8.888889       8.888889  12.500000
# 3            Jalan Kebun Limau   457.0   9.166667       9.166667  13.055556
# 4  Jurong Town Hall Rd/Exit 13  1734.0  21.388890      21.388890  20.833334
#
#    jamFactor  confidence  start_lat  start_lon  end_lat    end_lon
# 0        0.0        0.92    1.33174  103.96608  1.33246  103.96649
# 1        0.0        0.70    1.33174  103.96608  1.33246  103.96649
# 2        1.9        0.76    1.33174  103.96608  1.33246  103.96649
# 3        1.8        0.99    1.33174  103.96608  1.33246  103.96649
# 4        0.0        0.99    1.33174  103.96608  1.33246  103.96649

# %%
'''
yo = requests.get("https://data.traffic.hereapi.com/v7/flow?in=circle:1.279683,103.809628;r=20830&locationReferencing=olr&apiKey=uAF0ydU9hJ_THCHkwvtSQR5FhTKEWjtX8XynT5rHoPk")
ya = yo.json()["results"]
ye = pd.DataFrame(ya)
ye = pd.concat([ye['location'].apply(pd.Series)])
ye.head()
head1 = df["description"].unique().tolist()
head2 = ye["description"].unique().tolist()
len(head1)
len(head2)

if set(head1) == set(head2):
    print("The lists have the same contents.")
else:
    print("The lists have different contents.")
'''
# Out:
# '\nyo = requests.get("https://data.traffic.hereapi.com/v7/flow?in=circle:1.279683,103.809628;r=20830&locationReferencing=olr&apiKey=uAF0ydU9hJ_THCHkwvtSQR5FhTKEWjtX8XynT5rHoPk")\nya = yo.json()["results"]\nye = pd.DataFrame(ya)\nye = pd.concat([ye[\'location\'].apply(pd.Series)])\nye.head()\nhead1 = df["description"].unique().tolist()\nhead2 = ye["description"].unique().tolist()\nlen(head1)\nlen(head2)\n\nif set(head1) == set(head2):\n    print("The lists have the same contents.")\nelse:\n    print("The lists have different contents.")\n'

# %% [markdown]
# # Handling duplicate data

# %%
duplicates = df.duplicated(subset='description', keep=False)
duplicate_df = df[duplicates]

# %%
duplicate_df
# Out:
#                               description  length      speed  speedUncapped  \
# 0                      Changi South Ave 2    92.0  11.666667      11.666667
# 2                                Benoi Rd   511.0   8.888889       8.888889
# 3                       Jalan Kebun Limau   457.0   9.166667       9.166667
# 4             Jurong Town Hall Rd/Exit 13  1734.0  21.388890      21.388890
# 5                            Syed Alwi Rd    35.0   5.277778       5.277778
# ...                                   ...     ...        ...            ...
# 5510  TOH TUCK AVE NB AND TOH TUCK AVE SB   144.0  13.333334      13.333334
# 5511                     CTE/Central Expy   892.0  11.944445      11.944445
# 5512             Tavistock Ave/Berwick Dr    31.0   6.388889       6.388889
# 5514                           Marina Grv   146.0  13.611112      13.611112
# 5515                       Tiong Bahru Rd   574.0  10.277778      10.277778
#
#        freeFlow  jamFactor  confidence  start_lat  start_lon  end_lat  \
# 0     10.277778        0.0        0.92    1.33174  103.96608  1.33246
# 2     12.500000        1.9        0.76    1.33174  103.96608  1.33246
# 3     13.055556        1.8        0.99    1.33174  103.96608  1.33246
# 4     20.833334        0.0        0.99    1.33174  103.96608  1.33246
# 5      7.777778        1.7        0.84    1.33174  103.96608  1.33246
# ...         ...        ...         ...        ...        ...      ...
# 5510  13.888889        0.3        0.99    1.33174  103.96608  1.33246
# 5511  12.222222        0.3        0.93    1.33174  103.96608  1.33246
# 5512   6.388889        0.0        0.70    1.33174  103.96608  1.33246
# 5514  11.111112        0.0        0.99    1.33174  103.96608  1.33246
# 5515   9.444445        0.0        0.85    1.33174  103.96608  1.33246
#
#         end_lon
# 0     103.96649
# 2     103.96649
# 3     103.96649
# 4     103.96649
# 5     103.96649
# ...         ...
# 5510  103.96649
# 5511  103.96649
# 5512  103.96649
# 5514  103.96649
# 5515  103.96649
#
# [5191 rows x 11 columns]

# %%
unique_df = df[~df.duplicated(subset='description', keep=False)]

# %%
unique_df
# Out:
#                                         description  length      speed  \
# 1                               ECP/East Coast Pkwy    44.0  17.777779
# 39                      Frankel Ave/Jalan Kembangan   650.0  10.000000
# 40    BEDOK NORTH AVE 3 NB AND BEDOK NORTH AVE 3 SB   337.0  12.777778
# 51                    Upp Bukit Timah Rd/Dunearn Rd   394.0  10.833334
# 84                            THOMSON RD SOUTHBOUND   316.0  11.944445
# ...                                             ...     ...        ...
# 5446                           Upper Bukit Timah Rd    96.0  16.666668
# 5460                            KEPPEL RD WESTBOUND   567.0  16.388890
# 5469                     ANG MO KIO AVE 3 EASTBOUND    46.0   8.333334
# 5500                                      Marina PL    20.0  11.111112
# 5513                      TAMPINES ST 31 SOUTHBOUND   276.0  13.611112
#
#       speedUncapped   freeFlow  jamFactor  confidence  start_lat  start_lon  \
# 1         17.777779  13.888889        0.0        0.70    1.33174  103.96608
# 39        10.000000  13.333334        1.5        0.96    1.33174  103.96608
# 40        12.777778  14.166667        0.3        0.84    1.33174  103.96608
# 51        10.833334  13.888889        1.4        0.99    1.33174  103.96608
# 84        11.944445  10.833334        0.0        0.73    1.33174  103.96608
# ...             ...        ...        ...         ...        ...        ...
# 5446      17.777779  16.666668        0.0        0.99    1.33174  103.96608
# 5460      16.388890  15.555556        0.0        0.99    1.33174  103.96608
# 5469       8.333334  11.111112        1.2        0.99    1.33174  103.96608
# 5500      11.111112   9.166667        0.0        0.99    1.33174  103.96608
# 5513      13.611112  11.111112        0.0        0.90    1.33174  103.96608
#
#       end_lat    end_lon
# 1     1.33246  103.96649
# 39    1.33246  103.96649
# 40    1.33246  103.96649
# 51    1.33246  103.96649
# 84    1.33246  103.96649
# ...       ...        ...
# 5446  1.33246  103.96649
# 5460  1.33246  103.96649
# 5469  1.33246  103.96649
# 5500  1.33246  103.96649
# 5513  1.33246  103.96649
#
# [311 rows x 11 columns]

# %%
unique_list = []
duplicated = []

for item in df["description"].tolist():
    if item in unique_list:
        #print(item)
        duplicated.append(item)
    else:
        unique_list.append(item)

# %%
print("Duplicate records: ", len(duplicated), "\nUnique records:    ", len(unique_list))
# Out:
# Duplicate records:  3964
# Unique records:     1538

# %% [markdown]
# **There should only be 1538 rows after we handled the duplicate data**

# %% [markdown]
# ### Aggregating the duplicate rows
# **Sum the length feature, calculate the weighted average for speed, speedUncapped, freeFlow**

# %%
road_aggregated_data = {}

for _, row in duplicate_df.iterrows():
    road_name = row['description']
    start_lat = row['start_lat']
    start_lon = row['start_lon']
    end_lat = row['end_lat']
    end_lon = row['end_lon']
    length = row['length']
    speed = row['speed']
    speed_uncapped = row['speedUncapped']
    free_flow = row['freeFlow']
    jam_factor = row['jamFactor']
    confidence = row['confidence']
    
    if road_name in road_aggregated_data:
        (
            cumulative_length,
            cumulative_weighted_speed,
            cumulative_weighted_speed_uncapped,
            cumulative_weighted_free_flow,
            cumulative_weighted_jam_factor
        ) = road_aggregated_data[road_name][4:9]
        
        cumulative_length += length
        cumulative_weighted_speed += length * speed
        cumulative_weighted_speed_uncapped += length * speed_uncapped
        cumulative_weighted_free_flow += length * free_flow
        cumulative_weighted_jam_factor += length * jam_factor
        
        road_aggregated_data[road_name] = (
            start_lat,
            start_lon,
            end_lat,
            end_lon,
            cumulative_length,
            cumulative_weighted_speed,
            cumulative_weighted_speed_uncapped,
            cumulative_weighted_free_flow,
            cumulative_weighted_jam_factor,
            confidence
        )
    else:
        road_aggregated_data[road_name] = (
            start_lat,
            start_lon,
            end_lat,
            end_lon,
            length,
            length * speed,
            length * speed_uncapped,
            length * free_flow,
            length * jam_factor,
            confidence
        )

road_average_speeds = {}

for road_name, (
    start_lat,
    start_lon,
    end_lat,
    end_lon,
    cumulative_length,
    cumulative_weighted_speed,
    cumulative_weighted_speed_uncapped,
    cumulative_weighted_free_flow,
    cumulative_weighted_jam_factor,
    confidence
) in road_aggregated_data.items():
    average_speed = cumulative_weighted_speed / cumulative_length
    average_speed_uncapped = cumulative_weighted_speed_uncapped / cumulative_length
    average_free_flow = cumulative_weighted_free_flow / cumulative_length
    average_weighted_jam_factor = cumulative_weighted_jam_factor / cumulative_length
    
    road_average_speeds[road_name] = (
        start_lat,
        start_lon,
        end_lat,
        end_lon,
        cumulative_length,
        average_speed,
        average_speed_uncapped,
        average_free_flow,
        average_weighted_jam_factor,
        confidence
    )

# %%
result_df = pd.DataFrame(list(road_average_speeds.values()), columns=['start_lat', 'start_lon', 'end_lat', 'end_lon', 'length', 'speed', 'speedUncapped', 'freeFlow', 'jamFactor', 'confidence'])
result_df.insert(0, 'description', list(road_average_speeds.keys()))

# %%
result_df
# Out:
#                       description  start_lat  start_lon  end_lat    end_lon  \
# 0              Changi South Ave 2    1.33174  103.96608  1.33246  103.96649
# 1                        Benoi Rd    1.33174  103.96608  1.33246  103.96649
# 2               Jalan Kebun Limau    1.33174  103.96608  1.33246  103.96649
# 3     Jurong Town Hall Rd/Exit 13    1.33174  103.96608  1.33246  103.96649
# 4                    Syed Alwi Rd    1.33174  103.96608  1.33246  103.96649
# ...                           ...        ...        ...      ...        ...
# 1222      N Buona Vista Rd/Exit 8    1.33174  103.96608  1.33246  103.96649
# 1223    Pioneer Circus/Pioneer Rd    1.33174  103.96608  1.33246  103.96649
# 1224              Fort Rd/Exit 13    1.33174  103.96608  1.33246  103.96649
# 1225        Penang Rd/Somerset Rd    1.33174  103.96608  1.33246  103.96649
# 1226      Toa Payoh South Flyover    1.33174  103.96608  1.33246  103.96649
#
#        length      speed  speedUncapped   freeFlow  jamFactor  confidence
# 0      1631.0   9.147422       9.147422   9.661762   0.768670        0.70
# 1     11861.0  10.669187      10.669187  12.753281   0.869244        0.87
# 2       589.0   8.481890       8.481890  12.682041   2.158574        0.99
# 3      2963.0  20.467152      20.467152  21.178986   0.580695        0.99
# 4       176.0   7.058081       7.058081   8.222854   0.338068        0.90
# ...       ...        ...            ...        ...        ...         ...
# 1222   3050.0  21.559746      21.559746  21.485065   0.207738        0.99
# 1223   3457.0  13.642047      13.642047  14.629737   0.500000        0.99
# 1224   2250.0  22.150001      22.150001  23.538889   0.830400        0.99
# 1225    172.0   5.394057       5.394057   6.143411   0.202326        0.90
# 1226   1034.0  13.888889      14.867290  11.352891   0.000000        0.94
#
# [1227 rows x 11 columns]

# %% [markdown]
# **Verify the aggregated data**

# %%
result_df.loc[result_df['description']=='1/Jalan Tun Abdul Razak']
# Out:
#                  description  start_lat  start_lon  end_lat    end_lon  \
# 950  1/Jalan Tun Abdul Razak    1.33174  103.96608  1.33246  103.96649
#
#      length     speed  speedUncapped   freeFlow  jamFactor  confidence
# 950   892.0  7.473842       7.473842  11.456153   2.725336         0.7

# %%
duplicate_df.loc[df["description"]=="1/Jalan Tun Abdul Razak"]
# Out:
#                   description  length     speed  speedUncapped   freeFlow  \
# 2222  1/Jalan Tun Abdul Razak   758.0  7.777778       7.777778  12.222222
# 5193  1/Jalan Tun Abdul Razak    86.0  5.555556       5.555556   7.222222
# 5418  1/Jalan Tun Abdul Razak    48.0  6.111111       6.111111   6.944445
#
#       jamFactor  confidence  start_lat  start_lon  end_lat    end_lon
# 2222        3.0        0.73    1.33174  103.96608  1.33246  103.96649
# 5193        1.1        0.72    1.33174  103.96608  1.33246  103.96649
# 5418        1.3        0.70    1.33174  103.96608  1.33246  103.96649

# %% [markdown]
# **Combine the unique records with the aggregated records**

# %%
clean_df = pd.concat([unique_df, result_df])

# %%
clean_df.head()
# Out:
#                                       description  length      speed  \
# 1                             ECP/East Coast Pkwy    44.0  17.777779
# 39                    Frankel Ave/Jalan Kembangan   650.0  10.000000
# 40  BEDOK NORTH AVE 3 NB AND BEDOK NORTH AVE 3 SB   337.0  12.777778
# 51                  Upp Bukit Timah Rd/Dunearn Rd   394.0  10.833334
# 84                          THOMSON RD SOUTHBOUND   316.0  11.944445
#
#     speedUncapped   freeFlow  jamFactor  confidence  start_lat  start_lon  \
# 1       17.777779  13.888889        0.0        0.70    1.33174  103.96608
# 39      10.000000  13.333334        1.5        0.96    1.33174  103.96608
# 40      12.777778  14.166667        0.3        0.84    1.33174  103.96608
# 51      10.833334  13.888889        1.4        0.99    1.33174  103.96608
# 84      11.944445  10.833334        0.0        0.73    1.33174  103.96608
#
#     end_lat    end_lon
# 1   1.33246  103.96649
# 39  1.33246  103.96649
# 40  1.33246  103.96649
# 51  1.33246  103.96649
# 84  1.33246  103.96649

# %%
clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1538 entries, 1 to 1226
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   description    1538 non-null   object
#  1   length         1538 non-null   float64
#  2   speed          1538 non-null   float64
#  3   speedUncapped  1538 non-null   float64
#  4   freeFlow       1538 non-null   float64
#  5   jamFactor      1538 non-null   float64
#  6   confidence     1538 non-null   float64
#  7   start_lat      1538 non-null   float64
#  8   start_lon      1538 non-null   float64
#  9   end_lat        1538 non-null   float64
#  10  end_lon        1538 non-null   float64
# dtypes: float64(10), object(1)
# memory usage: 144.2+ KB

# %% [markdown]
# **length (and jamFactor and confidence too perhaps), remove 12 and**

# %% [markdown]
# **use the shape for unique identification of road name, check if it is true**

# %%
clean_df = clean_df.drop("confidence", axis=1)

# %%
sorted_df = clean_df.sort_values("description")

# %%
sorted_df['road_id'] = pd.factorize(sorted_df['description'])[0] + 1

# %%
clean_df.corr()
# Out:
#                  length     speed  speedUncapped  freeFlow  jamFactor  \
# length         1.000000  0.174647       0.164839  0.215871  -0.013400
# speed          0.174647  1.000000       0.991400  0.910031  -0.608016
# speedUncapped  0.164839  0.991400       1.000000  0.893933  -0.615057
# freeFlow       0.215871  0.910031       0.893933  1.000000  -0.295453
# jamFactor     -0.013400 -0.608016      -0.615057 -0.295453   1.000000
# start_lat           NaN       NaN            NaN       NaN        NaN
# start_lon           NaN       NaN            NaN       NaN        NaN
# end_lat             NaN       NaN            NaN       NaN        NaN
# end_lon             NaN       NaN            NaN       NaN        NaN
# road_id        0.018824  0.058676       0.047881  0.092960   0.047123
#
#                start_lat  start_lon  end_lat  end_lon   road_id
# length               NaN        NaN      NaN      NaN  0.018824
# speed                NaN        NaN      NaN      NaN  0.058676
# speedUncapped        NaN        NaN      NaN      NaN  0.047881
# freeFlow             NaN        NaN      NaN      NaN  0.092960
# jamFactor            NaN        NaN      NaN      NaN  0.047123
# start_lat            NaN        NaN      NaN      NaN       NaN
# start_lon            NaN        NaN      NaN      NaN       NaN
# end_lat              NaN        NaN      NaN      NaN       NaN
# end_lon              NaN        NaN      NaN      NaN       NaN
# road_id              NaN        NaN      NaN      NaN  1.000000

# %%
sorted_df
# Out:
#                                             description  length      speed  \
# 950                             1/Jalan Tun Abdul Razak   892.0   7.473842
# 1100                                                 12    52.0  13.888889
# 4915                             15A/Woodsville Flyover    75.0   5.000000
# 609                                 17/Jalan Pekeliling   931.0  13.784461
# 1189  188/Jalan Lingkaran Dalam Johor Bahru/Johor Ba...   747.0   9.095270
# ...                                                 ...     ...        ...
# 1035                             Yishun Ring Rd (South)  1516.0   9.083847
# 204                                       Yuan Ching Rd  1157.0   9.324162
# 1096                             Yuan Ching Rd/Exit 15B  1421.0  19.782432
# 1119                    Yuan Ching Rd/Jurong West St 51  2088.0   9.935079
# 318                                             Zion Rd  2441.0   6.493582
#
#       speedUncapped   freeFlow  jamFactor  start_lat  start_lon  end_lat  \
# 950        7.473842  11.456153   2.725336    1.33174  103.96608  1.33246
# 1100      15.833334  13.888889   0.000000    1.33174  103.96608  1.33246
# 4915       5.000000   7.777778   2.000000    1.33174  103.96608  1.33246
# 609       13.784461  15.210945   0.940602    1.33174  103.96608  1.33246
# 1189       9.095270  14.194557   3.003614    1.33174  103.96608  1.33246
# ...             ...        ...        ...        ...        ...      ...
# 1035       9.083847  12.122728   1.767084    1.33174  103.96608  1.33246
# 204        9.324162  11.461635   0.917113    1.33174  103.96608  1.33246
# 1096      19.782432  21.042695   0.979803    1.33174  103.96608  1.33246
# 1119       9.935079  14.534643   2.623372    1.33174  103.96608  1.33246
# 318        6.510424  10.024467   2.498894    1.33174  103.96608  1.33246
#
#         end_lon  road_id
# 950   103.96649        1
# 1100  103.96649        2
# 4915  103.96649        3
# 609   103.96649        4
# 1189  103.96649        5
# ...         ...      ...
# 1035  103.96649     1534
# 204   103.96649     1535
# 1096  103.96649     1536
# 1119  103.96649     1537
# 318   103.96649     1538
#
# [1538 rows x 11 columns]

# %%
metadata = sorted_df[["road_id", "description", "length", "start_lat", "start_lon", "end_lat", "end_lon"]]

# %%
metadata
# Out:
#       road_id                                        description  length  \
# 950         1                            1/Jalan Tun Abdul Razak   892.0
# 1100        2                                                 12    52.0
# 4915        3                             15A/Woodsville Flyover    75.0
# 609         4                                17/Jalan Pekeliling   931.0
# 1189        5  188/Jalan Lingkaran Dalam Johor Bahru/Johor Ba...   747.0
# ...       ...                                                ...     ...
# 1035     1534                             Yishun Ring Rd (South)  1516.0
# 204      1535                                      Yuan Ching Rd  1157.0
# 1096     1536                             Yuan Ching Rd/Exit 15B  1421.0
# 1119     1537                    Yuan Ching Rd/Jurong West St 51  2088.0
# 318      1538                                            Zion Rd  2441.0
#
#       start_lat  start_lon  end_lat    end_lon
# 950     1.33174  103.96608  1.33246  103.96649
# 1100    1.33174  103.96608  1.33246  103.96649
# 4915    1.33174  103.96608  1.33246  103.96649
# 609     1.33174  103.96608  1.33246  103.96649
# 1189    1.33174  103.96608  1.33246  103.96649
# ...         ...        ...      ...        ...
# 1035    1.33174  103.96608  1.33246  103.96649
# 204     1.33174  103.96608  1.33246  103.96649
# 1096    1.33174  103.96608  1.33246  103.96649
# 1119    1.33174  103.96608  1.33246  103.96649
# 318     1.33174  103.96608  1.33246  103.96649
#
# [1538 rows x 7 columns]

# %%
metadata.to_csv("metadata.csv", index=False)
